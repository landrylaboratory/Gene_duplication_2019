# %% [markdown]
# # Interface conservation human
#
# This is the final script that will do the analyses of the sequence identity of paralogs at the interface for human proteins.

# %%
# Load libraries
import csv
import re
import os
import glob
from collections import OrderedDict
import math
from Bio.PDB import *
from Bio import SeqIO
from Bio.Seq import *
from Bio.SeqRecord import *
from Bio.Align.Applications import MuscleCommandline
from shutil import copyfile
import copy

# %%
# Define paths to input folders
input_PDB = <path> # Folder with all the PDB files
phylomeDB_path = <path> # Path to the alignments from PhylomeDB
path_reference_proteome = <path> # Path to the reference proteome

# Define paths to output_folders
output_path = <path> # A parent folder for all the outputs
output_004_bio_assemblies = <path> # Biological assemblies for each input PDB
output_005_chain_match_tables = <path> # Chain match tables explaining which chains in the biological assembly come from which chain in the asymmetric unit
output_006_dist_interfaces = <path> # Files with the calculated interfaces
output_007_interface_dict = <path> # Files specifying which residues from each chain belong in interfaces
output_008_phylo_PDB_seq = <path> # FASTA files containing PhylomeDB alignments, the paralogs, and the PDB sequence
output_009_phylo_PDB_aln = <path> # FASTA files containing the aligned sequences from the output_008_phylo_seq folder
output_010_only_PDB_positions = <path> # FASTA files containing the parts of the alignment that correspond to the region observed in the PDB structure
output_011_only_interfaces = <path> # FASTA files containing the parts of the alignment that correspond to the interfaces observed in the PDB structure
output_012_only_non_interfaces = <path> # FASTA files containing the parts of the alignment that correspond to the non-interfaces observed in the PDB structure

# %%
def add2dict(dictionary, key, value):
    '''This is a small function I can use to add values to dictionaries. If the key is not
    already in the dictionary, then it initializes its value as a list with one element (value).
    Otherwise, it appends to that list.'''
    
    if dictionary.get(key, [-1]) == [-1]:
        dictionary[key] = value
    else:
        curr_val = list(dictionary[key])
        dictionary[key] = curr_val.append(value)
    
    return dictionary

# %%
# Prepare a dictionary of the gene IDs to their sequences
human_proteome = SeqIO.parse(path_reference_proteome, 'fasta')
                             
# Initialize the dictionary
proteome_dict = OrderedDict()
isoform_dict = OrderedDict()
isoform_to_gene_dict = OrderedDict()

# Loop through the entries in the reference proteome and and make a dictionary of the gene ID to the sequence
for record in human_proteome:
    for entry in record.description.split(' '):
        # Extract the entry with the gene ID
        if entry.startswith('gene:'):
            # Retrieve the gene ID without the '.X' at the end
            gene_id = entry.split(':')[1].split('.')[0]
            
    # Save all the isoforms for this gene
    if isoform_dict.get(gene_id, -1) == -1:
        # Save the first sequence I see for this gene ID
        isoform_dict[gene_id] = OrderedDict()
        isoform_dict[gene_id][record.id] = record
    else:
        # Add this isoform to the others
        isoform_dict[gene_id][record.id] = record
            
    # Map this isoform to its gene
    isoform_to_gene_dict[record.id] = gene_id

# %% [markdown]
# ## 1.- Map each of the paralog pairs to their corresponding structures

# %%
superseeded_dict = OrderedDict()
superseeded_dict['5len'] = '6f5e'
superseeded_dict['3ou5'] = '6dk3'

# %%
handle_in = open('Data/paralogs_PDB_structures_best_structures_over50.txt', 'r')

reader = csv.reader(handle_in, delimiter = '\t')

paralogs2structures = OrderedDict()

# Skip header
header = reader.next()

for line in reader:
    P1 = line[0]
    P2 = line[1]
    HET = line[4]
    P1_HM = line[5]
    P2_HM = line[6]
    
    # Save the pair of paralogs as a key in the dictionary
    paralogs2structures = add2dict(paralogs2structures, (P1, P2), OrderedDict())
    
    # Add each of the complexes only if it is not NA
    if P1_HM != 'NA':
        # Check if this is one of the superseeded structures
        if superseeded_dict.get(P1_HM, -1) != -1:
            P1_HM = superseeded_dict[P1_HM]
            
        paralogs2structures[(P1, P2)] = add2dict(paralogs2structures[(P1, P2)], 'P1_HM', P1_HM)
    if P2_HM != 'NA':
        # Check if this is one of the superseeded structures
        if superseeded_dict.get(P2_HM, -1) != -1:
            P2_HM = superseeded_dict[P2_HM]
            
        paralogs2structures[(P1, P2)] = add2dict(paralogs2structures[(P1, P2)], 'P2_HM', P2_HM)
    if HET != 'NA':
        # Check if this is one of the superseeded structures
        if superseeded_dict.get(HET, -1) != -1:
            HET = superseeded_dict[HET]
        
        paralogs2structures[(P1, P2)] = add2dict(paralogs2structures[(P1, P2)], 'HET', HET)

handle_in.close()

# %% [markdown]
# ## 2.- Get the needed biological assemblies

# %%
# Keep track of the assemblies I have already calculated
already_calculated = OrderedDict()

# Use a loop to call the script that generates the biological assemblies
for paralog_pair, struct_dict in paralogs2structures.items():
    for key, structure in struct_dict.items():
        assembly = structure[5:]
        pdb = structure[0:4]
        if already_calculated.get(pdb, -1) == -1:
            already_calculated[pdb] = 1
            call_script = 'python ../scripts_for_simulations/001_generate_bio_assembly.py '
            arg1 = '-i ' + input_PDB + '/' + pdb + '.pdb '
            arg2 = '-o ' + output_004_bio_assemblies + structure + '.pdb '
            arg3 = '-n ' + assembly + ' '
            arg4 = '-t ' + output_005_chain_match_tables + pdb + '_chain_table.txt'
            command = call_script + arg1 + arg2 + arg3 + arg4
            os.system(command)

# %% [markdown]
# ## 3.- Use the matching tables and the previous alignments to know which chains correspond to my proteins of interest

# %%
# Load the alignment data as a dictionary
alignment_dict = OrderedDict()
alignment_dict2 = OrderedDict()
handle_in = open('/media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/003_data_tables/PDB_matches.txt', 'r')
reader = csv.reader(handle_in, delimiter = '\t')

unspecific_dict = OrderedDict()
dup_type_dict = OrderedDict()

for line in reader:
    P1 = line[0]
    P2_list = line[14].split(',')
    
    
    # Skip the first line
    if P1 == 'P1':
        continue

    P1_match_PDB = line[1]
    P1_match_chain = line[2]
    evalue = float(line[11])
    # Save the matches to the second dictionary
    if alignment_dict2.get(P1, -1) == -1:
        alignment_dict2[P1] = OrderedDict()
    
    alignment_dict2[P1][(P1_match_PDB, P1_match_chain)] = evalue
    
    for P2 in P2_list:
        pair_list = [P1, P2]
        pair_list.sort()
        pair = tuple(pair_list)

        # Start filling the dictionary
        if alignment_dict.get(pair, -1) == -1:
            # First level
            alignment_dict[pair] = OrderedDict()

            # Second level
            alignment_dict[pair][P1] = OrderedDict()
            alignment_dict[pair][P2] = OrderedDict()

            # Third level
            alignment_dict[pair][P1][P1_match_PDB] = [P1_match_chain]

        # When adding a new PDB structure
        elif alignment_dict[pair][P1].get(P1_match_PDB, -1) == -1:
            alignment_dict[pair][P1][P1_match_PDB] = [P1_match_chain]

        # When adding chains to a PDB structure
        else:
            alignment_dict[pair][P1][P1_match_PDB].append(P1_match_chain)

# %%
file_list = glob.glob(output_005_chain_match_tables + '/*')

chain_dict = OrderedDict()
for match_table in file_list:
    structure = match_table.split('/')[-1][0:4]
    handle = open(match_table, 'r')
    reader = csv.reader(handle, delimiter = '\t')
    chain_dict[structure] = OrderedDict()
    for line in reader:
        key = line[0]
        values = line[1].split(',')
        chain_dict[structure][key] = values

# %% [markdown]
# ## 4.- Call the interfaces in each biological assembly

# %%
def parse_pdb_line(pdb_line):
    '''This function will receive a line from a PDB file and parse it as a list. It will do so based on the
    PDB format explanation from this site:

    https://www.cgl.ucsf.edu/chimera/docs/UsersGuide/tutorials/pdbintro.html
    '''
    atom = pdb_line[0:4].strip(' ')
    atom_num = pdb_line[6:11].strip(' ')
    atom_name = pdb_line[12:16].strip(' ')
    resname = pdb_line[17:20].strip(' ')
    chain = pdb_line[21]
    res_num = pdb_line[22:26].strip(' ')
    x = pdb_line[30:38].strip(' ')
    y = pdb_line[38:46].strip(' ')
    z = pdb_line[46:54].strip(' ')
    region = float(pdb_line[61:66].strip())

    return [atom, atom_num, atom_name, resname, chain, res_num, x, y, z, region]

##################################

def replace_b_factor(pdb_infile, in_dict, outfile):
    '''This function uses an input PDB file, selects the lines that correspond to the atoms, and replaces their
    b-factor values with the relative SASA from the dictionary. The output is written directly to a the outfile.'''
    in_handle = open(pdb_infile, 'r')
    out_handle = open(outfile, 'w')

    for line in in_handle:
        if line.startswith('ATOM'):

            parsed_line = parse_pdb_line(line)

            # Ignore DNA sequences
            if parsed_line[3] in ['DA', 'DG', 'DC', 'DT', 'A', 'C', 'G', 'T', 'U']:
                continue
        
            chain = parsed_line[4]
            resid = parsed_line[5] + parsed_line[3]

            dict_sasa = str(in_dict[chain].get(resid, 0.0)) +'0'
            final_sasa = (6-len(dict_sasa))*' ' + dict_sasa

            final_line = line.replace(line[60:66], final_sasa)
            out_handle.write(final_line)

    # Once the loop has finished, I can close the outfile
    out_handle.close()

##################################

# Define a class for PDB coordinates
class PDB_coordinates:
    def __init__(self, x_coord, y_coord, z_coord, residue, atomtype):
        '''The constructor for the PDB coordinates class'''
        self.x = x_coord
        self.y = y_coord
        self.z = z_coord
        self.residue = residue
        self.atomtype = atomtype

    def measure_distance(self, target):
        '''A function I can use to measure the distance between two PDB_coordinates objects.'''
        x_dist = (self.x - target.x)**2
        y_dist = (self.y - target.y)**2
        z_dist = (self.z - target.z)**2
        return math.sqrt(x_dist + y_dist + z_dist)

##################################

def parse_coordinates(infile, alpha_only):
    '''This function will parse a pdb file using the PDB_coordinates class I defined.
    The "alpha_only" argument will help me decide if I only want alpha carbons ("CA")
    if it is True or all atoms if it is False.
    '''
    handle = open(infile, 'r')
    coord_dict = OrderedDict()

    for line in handle:
        if line.startswith('ATOM'):

            atom_line = parse_pdb_line(line)

            # Ignore DNA sequences
            if atom_line[3] in ['DA', 'DG', 'DC', 'DT', 'A', 'C', 'G', 'T', 'U']:
                continue
            
            if alpha_only:

                if atom_line[2] == 'CA':
                    if coord_dict.get(atom_line[4], -1) == -1:
                        coord_dict[atom_line[4]] = []
                    # Add the atom to the list
                    x_coord = float(atom_line[6])
                    y_coord = float(atom_line[7])
                    z_coord = float(atom_line[8])
                    residue = atom_line[4] + atom_line[5] + atom_line[3]
                    coord_dict[atom_line[4]].append(PDB_coordinates(x_coord, y_coord, z_coord, residue, 'CA'))
            else:
                if coord_dict.get(atom_line[4], -1) == -1:
                        coord_dict[atom_line[4]] = []
                # Add the atom to the list
                x_coord = float(atom_line[6])
                y_coord = float(atom_line[7])
                z_coord = float(atom_line[8])
                atomtype = atom_line[2]
                residue = atom_line[4] + atom_line[5] + atom_line[3]
                coord_dict[atom_line[4]].append(PDB_coordinates(x_coord, y_coord, z_coord, residue, atomtype))

    return coord_dict

##################################

def get_vdw_dict(infile):
    '''This function parses the FreeSasa file I will use as a reference for the van der Waals radii.
    '''
    handle = open(infile, 'r')

    vdw_dict = {}

    for line in handle:
        if line.startswith('ATOM'):
            line_list = re.split('\s+', line)

            aminoacid = line_list[3]
            atomtype = line_list[2]
            vdw_radius = float(line_list[9])
            # Add the amino acid if it has not been registered
            if vdw_dict.get(aminoacid, -1) == -1:
                vdw_dict[aminoacid] = {'OXT' : 1.46}
            # Add the vdw radius for the current atomtype for this aminoacid if it has not been registered
            if vdw_dict[aminoacid].get(atomtype, -1) == -1:
                vdw_dict[aminoacid][atomtype] = vdw_radius


    # Now that I finished, I can return the dictionary
    return vdw_dict

# ref_vdw_dict = '/Users/intermilan1102/Dropbox/All_paralogs/1aof_sasa.pdb'
ref_vdw_dict = '../scripts_for_simulations/Data/1aof_sasa.pdb'
vdw_dict = get_vdw_dict(ref_vdw_dict)

# %%
# Define the main function that will find interfaces
def distance_interfaces(pdb_file, out_pdb_dist):
    alpha_carbons = parse_coordinates(pdb_file, True)
    chains = alpha_carbons.keys()

    distance_region_dict = OrderedDict()
    for chain in chains:
        distance_region_dict[chain] = OrderedDict()

    all_atoms = parse_coordinates(pdb_file, False)

    alpha_carbon_residue_list = []
    
    for chainA_num in range(len(chains) - 1):
        chainA = chains[chainA_num]

        for chainB_num in range(chainA_num + 1, len(chains)):
            chainB = chains[chainB_num]
            
            # I will compare the distances for the alpha carbons
            for alphaA in alpha_carbons[chainA]:
                residueA = alphaA.residue[1:]
            
                for alphaB in alpha_carbons[chainB]:

                    residueB = alphaB.residue[1:]

                    # Use this code to distinguish regions
                    # 0.00 = neither nearby nor interacting
                    # 0.25 = interaction candidates (used to reduce the number of all-atom measurements)
                    # 0.75 = nearby
                    # 1.00 = interacting
                    if distance_region_dict[chainA].get(residueA, -1) != 0.25:
                        distance_region_dict[chainA][residueA] = 0.00

                    if distance_region_dict[chainB].get(residueB, -1) != 0.25:
                        distance_region_dict[chainB][residueB] = 0.00

                    # Get candidates based on their alpha carbons
                    if alphaA.measure_distance(alphaB) <= 10:

                        distance_region_dict[chainA][residueA] = 0.25
                        distance_region_dict[chainB][residueB] = 0.25

    # Save a dictionary of the residues that make up each interface
    interacting_dict = OrderedDict()
    for chainA_num in range(len(chains) - 1):
        chainA = chains[chainA_num]
        for chainB_num in range(chainA_num + 1, len(chains)):
            chainB = chains[chainB_num]
            interacting_dict[(chainA, chainB)] = [[], []]            
    
    # Look at all the atom pairwise comparisons between interacting candidates
    for chainA_num in range(len(chains) - 1):
        chainA = chains[chainA_num]
        for atomA in all_atoms[chainA]:
            residueA = atomA.residue[1:] 
            # Only keep going if this is a candidate
            if distance_region_dict[chainA].get(residueA, 0) >= 0.25:
                for chainB_num in range(chainA_num + 1, len(chains)):           
                    chainB = chains[chainB_num]
                    for atomB in all_atoms[chainB]:
                        residueB = atomB.residue[1:]
                        # Only keep going if this is a candidate
                        if distance_region_dict[chainB].get(residueB, 0) >= 0.25:

                            if not atomA.atomtype.startswith('H') and not atomB.atomtype.startswith('H'):
                                vdw_atomA = vdw_dict[residueA[-3:]][atomA.atomtype]
                                vdw_atomB = vdw_dict[residueB[-3:]][atomB.atomtype]
                                atom_distance = atomA.measure_distance(atomB)

                                # Check if the atoms are interacting
                                if atom_distance < vdw_atomA + vdw_atomB + 0.5:
                                    # I can list them as interacting residues
                                    distance_region_dict[chainA][residueA] = 1.00
                                    distance_region_dict[chainB][residueB] = 1.00

                                    # I can save them to the dictionary
                                    if not residueA in interacting_dict[(chainA, chainB)][0]:
                                        interacting_dict[(chainA, chainB)][0].append(residueA)
                                    if not residueB in interacting_dict[(chainA, chainB)][1]:
                                        interacting_dict[(chainA, chainB)][1].append(residueB)

    # Use the interacting residues to find the nearby residues 
    all_alpha = []
    for chain in chains:
        all_alpha = all_alpha + alpha_carbons[chain]
    
    # Keep track of comparisons to avoid repeating
    for pos1 in range(0,len(all_alpha)-1):

        alpha1 = all_alpha[pos1]
        residue1 = alpha1.residue[1:]
        chain1 = alpha1.residue[0]

        for pos2 in range(pos1+1, len(all_alpha)):
            alpha2 = all_alpha[pos2]
            residue2 = alpha2.residue[1:]
            chain2 = alpha2.residue[0]

            if alpha1.measure_distance(alpha2) <= 6:

                # If residueB is near an interacting residue, classify it as nearby
                if distance_region_dict[chain1][residue1] == 1.00 and distance_region_dict[chain2][residue2] < 0.75:
                    distance_region_dict[chain2][residue2] = 0.75
                    # Add the nearby residue to the interface dict
                    for chain_pair, interface_lists in interacting_dict.items():
                        if residue1 in interface_lists[0] and chain2 == chain_pair[0]:
                            interacting_dict[chain_pair][0].append(residue2)
                        if residue1 in interface_lists[1] and chain2 == chain_pair[1]:
                            interacting_dict[chain_pair][1].append(residue2)

                # If residueA is near an interacting residue, classify it as nearby
                if distance_region_dict[chain2][residue2] == 1.00 and distance_region_dict[chain1][residue1] < 0.75:
                    distance_region_dict[chain1][residue1] = 0.75
                    # Add the nearby residue to the interface dict
                    for chain_pair, interface_lists in interacting_dict.items():
                        if residue2 in interface_lists[0] and chain1 == chain_pair[0]:
                            interacting_dict[chain_pair][0].append(residue1)
                        if residue2 in interface_lists[1] and chain1 == chain_pair[1]:
                            interacting_dict[chain_pair][1].append(residue1)
    
    # Set interaction candidates that do not interact to non interfaces
    for chain in chains:
        for alpha_carbon in alpha_carbons[chain]:
            residue = alpha_carbon.residue[1:]
            chain = alpha_carbon.residue[0]
            if distance_region_dict[chain][residue] == 0.25:
                distance_region_dict[chain][residue] = 0.00

    # Write the new PDB file with the regions
    replace_b_factor(pdb_file, distance_region_dict, out_pdb_dist)
    
    return(interacting_dict)

# %% [markdown]
# This is the main block that calls interfaces.

# %%
# Get the list of files
file_list = glob.glob(output_004_bio_assemblies + '/*')

# Call interfaces
for pdb_file in file_list:
    print pdb_file
    structure = pdb_file.split('/')[-1][0:4]
    out_file = output_006_dist_interfaces + '/dist_regions_' + structure + '.pdb'
    interacting_dict = distance_interfaces(pdb_file, out_file)
    
    # Save the interacting dict to a file
    int_dict_file = open(output_007_interface_dict + '/' + structure + '_interface_dict.txt', 'w')
    writer = csv.writer(int_dict_file, delimiter = '\t')
    for key, value in interacting_dict.items():
        col1 = ','.join(key)
        col2_1 = ','.join(value[0])
        col2_2 = ','.join(value[1])
        col2 = col2_1 + ';' + col2_2
        writer.writerow([col1, col2])
    int_dict_file.close()
# Out:
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3a2c_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5t68_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3eb5_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2uv4_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2xyg_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1ehw_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2ihc_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3tjn_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2oni_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1jvg_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2x2e_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5x1c_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4l59_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4acq_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4a9z_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4p4u_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5j71_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4mjo_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3icu_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4b7w_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4om2_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4ypc_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1wyx_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3ljb_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1bhh_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2oan_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5a1i_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4id7_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1z8d_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3ibf_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5ijt_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2yi7_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3ohu_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4jnk_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4aya_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4u6s_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5iqp_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1zs6_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3p0f_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1aie_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2y4p_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3kvq_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2bp1_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3pxk_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1oki_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2wqj_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4hwt_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3g0f_2.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3gvp_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5fhz_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1my5_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1xfb_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4pvf_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1hvv_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5ifn_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3tq7_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2xv5_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4ova_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3lhr_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1oyx_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2p0a_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4wii_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3ddt_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4z54_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4tpt_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3te3_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5j87_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5khh_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3euf_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3hah_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3dds_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3ihl_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1hkx_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2w2c_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5l2m_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1cki_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1s9j_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2v66_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3abh_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1oa8_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3tyy_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5ky6_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2pzd_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5iko_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3bzh_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2p6v_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1qdv_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5vr6_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2zkj_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3l1g_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1quu_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3caf_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3q1d_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4yqu_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1vka_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4b3z_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4dhr_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4ju5_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2a7r_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3h9e_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4dnk_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4cn0_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2efl_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1zmu_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1ef1_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5ifm_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1u8f_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1i0z_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3sde_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1nf7_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2jc9_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5a6o_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4cl7_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3otf_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1s9p_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2efk_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1use_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1b47_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3zy1_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1dk8_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1khu_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3hrn_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/5t3q_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3cvf_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4xz2_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1t6n_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1s9i_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1j55_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/3lmn_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1uj2_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/4dyl_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/1flk_1.pdb
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/004_bio_assemblies/2ji4_1.pdb

# %% [markdown]
# ## 5.- Retrieve the interfaces and start looking at their conservation

# %%
integrated_table_file = 'Data/paralogs_PDB_structures_best_structures_over50.txt'

phylomedb_path = phylomeDB_path
desired_regions = [0.75, 1.00]

# %%
# Load the dictionary to convert ENSP IDs to PhylomeDB IDs
handle = open("Data/phylome_db_human_ENSG_ids.txt", 'r')
reader = csv.reader(handle, delimiter = '\t')

systematic2phylomeDB = OrderedDict()
phylomeDB2systematic = OrderedDict()
for line in reader:
    systematic2phylomeDB[line[2]] = line[0]
    phylomeDB2systematic[line[0]] = line[2]

# %%
# Define some functions
def align_seqs(in_fasta):
    '''This function will take the FASTA file with the PDB entry's sequences and
    align them. It will return a dictionary with the aligned sequences.
    '''
    muscle_cline = MuscleCommandline(input = in_fasta)
    stdout, stderr = muscle_cline()
    
    align_dict = {}
    for line in stdout.split('\n'):
        if line.startswith('>'):

            current_chain = line.split(' ')[0]

            if current_chain[1:] in align_dict.keys():
                current_chain = current_chain + '2'
            align_dict[current_chain[1:]] = ''
        else:
            align_dict[current_chain[1:]] = align_dict[current_chain[1:]] + line
        
    return align_dict

#########################################

def align2records(alignment):
    '''This function will receive a muscle alignment and change it into a list of records that can be saved.
    '''
    records = []
    for prot_id, sequence in alignment.items():
        new_record = SeqRecord(seq = Seq(sequence), id = prot_id, description = '')
        records.append(new_record)
    return records

#########################################

def percentage_identity(in_file):
    '''This function will receive a fasta file with two sequences and calculate their sequence identity.
    '''
    records = []
    for record in SeqIO.parse(in_file, 'fasta'):
        records.append(record)
    
    total_residues = len(record.seq)
    if total_residues == 0:
        return 0
    
    matches = 0.0
    dual_gaps = 0.0
    seq1 = records[0]
    seq2 = records[1]
    for pos in range(total_residues):
        if seq1[pos] == seq2[pos]:
            if seq1[pos] == '-':
                dual_gaps += 1.0
            else:
                matches = matches + 1.0
        
    return round(matches*100/(total_residues - dual_gaps), 2)

#########################################

def percentage_identity2(align_dict):
    '''This function will receive a dictionary with two sequences and calculate their sequence identity.
    '''
    seq1 = align_dict.values()[0]
    seq2 = align_dict.values()[1]
    
    total_residues = len(seq1)
    matches = 0.0
    dual_gaps = 0.0
    for pos in range(total_residues):
        if seq1[pos] == seq2[pos]:
            if seq1[pos] == '-':
                dual_gaps += 1.0
            else:
                matches = matches + 1.0
        
    return round(matches*100/(total_residues - dual_gaps), 2)

#########################################

def region_parser(interface_file, aa_dict):
    '''This function takes a PDB file in which regions have been called in order to identify the interfaces.
    It returns a dictionary in residues map to a two-element list:
    - First position: True if they belong to the desired regions and False otherwise
    - Second position: The ID of the region to which they belong
    '''
    
    interface_file_handle = open(interface_file, 'r')

    # Create a dictionary that will store the chains, its residues, and the regions to which they belong
    pdb_dict = OrderedDict()
    start_dict = OrderedDict()
    end_dict = OrderedDict()
    
    sequence_dict = OrderedDict()

    # Save the previous position number to make sure I deal with alternative coordinates
    prev_pos = 'X'
    
    # Parse the file into the dictionary
    for line in interface_file_handle:
        pdb_line = parse_pdb_line(line)

        # Add the data for this residue to the dictionary
        res_id = pdb_line[3] + pdb_line[5]
        region = pdb_line[9]
        chain = pdb_line[4]
        atom_type = pdb_line[2]
        
        # Keep track of the start and the end positions
        curr_pos = int(pdb_line[5])

        # Look at alpha carbons to avoid repeating
        if atom_type == 'CA' and prev_pos != curr_pos:

            prev_pos = curr_pos
            
            # Keep track of the start and end positions
            if not chain in start_dict.keys():
                start_dict[chain] = curr_pos
            elif start_dict[chain] > curr_pos:
                start_dict[chain] = curr_pos

            if not chain in end_dict.keys():
                end_dict[chain] = curr_pos
            elif end_dict[chain] < curr_pos:
                end_dict[chain] = curr_pos

            # Save the regions to which each residue belongs
            if pdb_dict.get(chain, -1) == -1:
                pdb_dict[chain] = OrderedDict()
                pdb_dict[chain][res_id] = region
            else:
                pdb_dict[chain][res_id] = region

            # Save sequences
            if sequence_dict.get(chain, -1) == -1:
                sequence_dict[chain] = aa_dict[res_id[0:3]]
            else:
                sequence_dict[chain] += aa_dict[res_id[0:3]]

            
    return pdb_dict, start_dict, end_dict, sequence_dict

#########################################

def extract_PDB_region(alignment_dict, P1_id, output_path):
    ''' This function will receive the alignment parsed as a dictionary and return the region of the alignment
    that corresponds to residues in the PDB sequence. It will write the resulting sequences to a file in
    the 007_only_PDB_positions folder in the output path.
    '''
    ### Using the MSA, extract the part of the sequences that match to the PDB.
    start = -1
    end = -1
    PDB_seq = alignment_dict[P1_id + "_pdb"].seq
    for pos in range(0,len(PDB_seq)):
        if PDB_seq[pos] != '-':
            # Then, I should assign this position to the end because it contains an amino acid
            end = pos
            # If this is the first one I see, I will save it as the start
            if start == -1:
                start = pos

    ### Knowing the start and end positions, I can save these sequences in the 007 folder.
    only_PDB_positions = []
    for key, record in alignment_dict.items():
        # I will only save the records that are not the PDB sequence
        if key != P1_id + "_pdb":
            new_record = SeqRecord(record.seq[start:end], id = key, description = '')
            only_PDB_positions.append(new_record)

    SeqIO.write(only_PDB_positions, os.path.join(output_path, P1_id + "_only_PDB_pos.fasta"), "fasta")
    return(PDB_seq)

#########################################

def fasta2list(in_fasta):
    ''' This function receives a multi fasta file and saves its records to a list.
    '''
    phylo_records = []
    for record in SeqIO.parse(in_fasta, "fasta"):
        phylo_records.append(record)
    return phylo_records

########################################

def fasta2dict(in_fasta):
    '''This function receives a multi fasta file and parses it into a dictionary.
    '''
    dict_out = OrderedDict()
    for record in SeqIO.parse(in_fasta, "fasta"):
        dict_out[record.id] = record
    return dict_out

# %%
# Add MSE (selenomethionine) as M and MLY (methylysine) as K
# Added UNK as X because there are sequences that have it in the reference human proteome
aa_dict = {
    'ALA':'A',
    'ARG':'R',
    'ASN': 'N',
    'ASP': 'D',
    'CYS':'C',
    'GLU':'E',
    'GLN':'Q',
    'GLY':'G',
    'HIS':'H',
    'ILE':'I',
    'LEU':'L',
    'LYS':'K',
    'MET':'M',
    'PHE':'F',
    'PRO':'P',
    'SER':'S',
    'THR':'T',
    'TRP':'W',
    'TYR':'Y',
    'VAL':'V',
    'MSE':'M',
    'MLY':'K',
    'UNK':'X'
}

aa2three_letter = OrderedDict()
for key, value in aa_dict.items():
    if key in ('MSE', 'MLY'):
        continue
    else:
        aa2three_letter[value] = key

desired_regions = [0.75, 1.00]

# %%
# Load the human reference proteome so that I can extract sequences easily
# Needed whenever the sequences are missing from the PhylomeDB alignments
proteome_dict = OrderedDict()

pdb_seqs = SeqIO.parse(path_reference_proteome, 'fasta')

for record in pdb_seqs:
    proteome_dict[record.id] = record

# %% [markdown]
# Preprocess the file with the best structures to determine the best isoforms for the matching structures.

# %%
def get_best_match(structure, chain, protein, best_matches_dict, isoform_list):
    '''This function will receive a structure that was matched to a protein in the alignment and check if that
    isoform is the one that best matches the chain in the structure.
    '''
    if best_matches_dict.get(structure, -1) == -1:
        best_matches_dict[structure] = OrderedDict()
        best_match = protein
        min_evalue = alignment_dict2[protein][(structure, chain)]
    else:
        best_match = best_matches_dict[structure].get(chain, protein)
        min_evalue = alignment_dict2[best_match][(structure, chain)]

    for isoform in isoform_list:

        match_dict = alignment_dict2.get(isoform, -1)
        if match_dict != -1:
            evalue_1 = match_dict.get((structure, chain), 1000)
            if evalue_1 < min_evalue:
                min_evalue = evalue_1
                best_match = isoform_1
    return(best_match)

# %%
integrated_table_file = 'Data/paralogs_PDB_structures_best_structures_over50.txt'

handle = open(integrated_table_file, 'r')
reader = csv.reader(handle, delimiter = '\t')

best_matches_dict = OrderedDict()

# Loop through each of the lines
for line in reader: 
    P1 = line[0]
    P2 = line[1]
    
    if P1 == 'P1_ID':
        continue
    
    HET = line[4]
    strict_HM_P1 = line[5]
    strict_HM_P2 = line[6]
    pair_list = [P1, P2]
    pair_list.sort()
    pair = tuple(pair_list)
    
    # Look at structures for Strict_HM_P1
    if strict_HM_P1 != 'NA':
        strict_HM_P1 = strict_HM_P1[0:4]
        
        # Get the IDs of the other isoforms of this gene
        gene_1 = isoform_to_gene_dict[P1]
        isoform_list_1 = isoform_dict[gene_1]
        
        # Compare evalues and keep the smallest one (start with the one in our current line)
        chains = alignment_dict[(pair)][P1][strict_HM_P1]
        
        for chain in chains:
            # Save match to a dictionary
            best_match = get_best_match(strict_HM_P1, chain, P1, best_matches_dict, isoform_list_1)

            best_matches_dict[strict_HM_P1][chain] = best_match
        
    # Look at structures for Strict_HM_P2
    if strict_HM_P2 != 'NA':
        strict_HM_P2 = strict_HM_P2[0:4]
        
        # Get the IDs of the other isoforms of this gene
        gene_2 = isoform_to_gene_dict[P2]
        isoform_list_2 = isoform_dict[gene_2]
        
        # Compare evalues and keep the smallest one (start with the one in our current line)
        chains = alignment_dict[(pair)][P2][strict_HM_P2]
        
        for chain in chains:
            # Save match to a dictionary
            best_match = get_best_match(strict_HM_P2, chain, P2, best_matches_dict, isoform_list_2)

            best_matches_dict[strict_HM_P2][chain] = best_match

    # Look at structures for HET
    if HET != 'NA':
        HET = HET[0:4]
        
        # Get the IDs of the other isoforms of these genes
        gene_1 = isoform_to_gene_dict[P1]
        isoform_list_1 = isoform_dict[gene_1]
        
        gene_2 = isoform_to_gene_dict[P2]
        isoform_list_2 = isoform_dict[gene_2]
        
        # Compare evalues and keep the smallest one (start with the one in our current line)
        chains_1 = alignment_dict[(pair)][P1][HET]
        chains_2 = alignment_dict[(pair)][P2][HET]
        
        for chain in chains_1:
            # Save match to a dictionary
            best_match = get_best_match(HET, chain, P1, best_matches_dict, isoform_list_1)
            best_matches_dict[HET][chain] = best_match
            
        for chain in chains_2:
            # Save match to a dictionary
            best_match = get_best_match(HET, chain, P2, best_matches_dict, isoform_list_2)
            best_matches_dict[HET][chain] = best_match 
        
handle.close()

# %%
# Use the best_matches_dict to get the final table, eliminating all the suboptimal matches
integrated_table_file = 'Data/paralogs_PDB_structures_best_structures_over50.txt'

handle = open(integrated_table_file, 'r')
reader = csv.reader(handle, delimiter = '\t')

outfile = output_path + '/paralogs_PDB_structures_best_structures_best_isoforms_over50.txt'

handle_out = open(outfile, 'w')
writer = csv.writer(handle_out, delimiter = '\t')

for line in reader:
    P1 = line[0]
    P2 = line[1]
    HM_P1 = line[2]
    HM_P2 = line[3]
    
    if P1 == 'P1_ID':
        writer.writerow(line)
        continue
    
    HET = line[4]
    strict_HM_P1 = line[5]
    strict_HM_P2 = line[6]
    pair_list = [P1, P2]
    pair_list.sort()
    pair = tuple(pair_list)
    
    # Write down the line only if it refers to the best matches
    if strict_HM_P1 != 'NA':
        if not P1 in best_matches_dict[strict_HM_P1[0:4]].values():
            strict_HM_P1 = 'NA'
            
    if strict_HM_P2 != 'NA':
        if not P2 in best_matches_dict[strict_HM_P2[0:4]].values():
            strict_HM_P2 = 'NA'
        
    if HET != 'NA':
        if not P1 in best_matches_dict[HET[0:4]].values() or not P2 in best_matches_dict[HET[0:4]].values():
            HET = 'NA'
    
    new_row = [P1, P2, HM_P1, HM_P2, HET, strict_HM_P1, strict_HM_P2]
    writer.writerow(new_row)

handle_out.close()

# %% [markdown]
# Start getting the sequence identity.

# %%
# I will define the functions to work with the PDB sequences here
def match_PDB_full_seq(align_dict, PDB_dict, full_seq_id, pdb_seq_id, aa2three_letter):
    '''This function will help me find assign PDB regions for the full sequence.
    '''
    # Retrieve the aligned sequences
    aligned_chain_pdb = align_dict[pdb_seq_id]
    aligned_chain_full = align_dict[full_seq_id]
    
    counter_pdb = 0
    counter_full = 0
    
    # Loop through the keys of the dictionary
    pdb_residues = PDB_dict.keys()
    
    match_list = []
    full_region_dict = OrderedDict()
    
    # Loop through the positions of the PDB chain
    for position in range(len(aligned_chain_pdb)):
        # Get the residue in this position 
        aligned_pdb = aligned_chain_pdb[position]
        
        if counter_pdb < len(pdb_residues):
            pdb_pos = pdb_residues[counter_pdb]
        else:
            pdb_pos = '---'
        
        # Get the residue in this position for the full sequence
        aligned_full = aligned_chain_full[position]
        
    
        # Look at the four possible scenarios with respect to gaps in the sequences
        if aligned_pdb == '-' and aligned_full == '-':
            continue
        elif aligned_pdb == '-' and aligned_full != '-':
            # This is a gap in the PDB sequence.
            full_pos = aa2three_letter[aligned_full] + str(counter_full)
            full_region_dict[full_pos] = -1
            match_list.append(['-', full_pos, -1])
            counter_full = counter_full + 1
        elif aligned_pdb != '-' and aligned_full == '-':
            # This is a gap in the full sequence. 
            counter_pdb = counter_pdb + 1
        elif aligned_pdb != '-' and aligned_full != '-':
            # Make sure that the alignment position residue type matches the query
            if aa2three_letter.get(aligned_pdb, -1) != pdb_pos[0:3]:
                # This will identify unusual residues
                print 'Found something else', pdb_pos, aligned_pdb, structure
            else:
                region = PDB_dict.get(pdb_pos, '-')
                # Save a dictionary with the matches
                full_pos = aa2three_letter[aligned_full] + str(counter_full)
                match_list.append([pdb_pos, full_pos, region])

                # Add one to the PDB counter and to the full counter
                counter_pdb = counter_pdb + 1
                counter_full = counter_full + 1

                full_region_dict[full_pos] = region

        #####################################
    
    # Return the dictionary that maps each residue in the sequence to the available structural information
    return full_region_dict, match_list

# %%
def first_round_alignments2(phylo_dict, phylo_ID, paralog_ID, alignment_dict, chain_dict):
    '''This function takes the dictionaries and does the first alignment, that is, the sequence from the PDB to
    the full protein, which will help identify the position of the interfaces in that full protein.
    '''
    needed_chains = alignment_dict[(P1, P2)][paralog_ID][structure[0:4]]
    for needed_chain in needed_chains:
        new_chain = chain_dict[structure[0:4]][needed_chain][0]
        if new_chain != '':
            break
    pdb_sequence = pdb_sequence_dict[new_chain]
    
    # The pdb_dict already has all residues that belong to the interface of at least one of the subunits
    PDB_sequence_record = SeqRecord(Seq(pdb_sequence), id = paralog_ID + '_pdb', description = '')

    # Make records with these two sequences and align them
    full_seq_record = phylo_dict[phylo_ID]
    records = [full_seq_record, PDB_sequence_record]

    pdb_seq_id = PDB_sequence_record.id
    full_seq_id = full_seq_record.id

    # Write the PDB sequence and the full sequence for that protein
    outpath = os.path.join(output_path_008_phylo_PDB_seq, phylo_ID + '.fasta')
    SeqIO.write(records, outpath, 'fasta')

    # Align with MUSCLE
    aln_dict = align_seqs(outpath)
    
    # Use the alignment dict to know where the PDB chain matches the full sequence 
    full_region_dict, match_list = match_PDB_full_seq(aln_dict, pdb_dict[new_chain], full_seq_id, pdb_seq_id, aa2three_letter)
    
    return full_region_dict, match_list
    
    ####################################

# %%
def save_final_sequences2(phylo_dict, full_region_dict, phylo_ID_2, phylo_ID, aa2three_letter):
    '''This function transfers the annotation to the second paralog and writes the final files.'''

    full_region_dict_2, match_list_2 = match_PDB_full_seq(phylo_dict, full_region_dict, phylo_ID_2, phylo_ID, aa2three_letter)
    
    # From here, the match_lists should be enough to get sequence identities
    pdb_seqs = ['','']
    only_interfaces = ['','']
    only_non_interfaces = ['','']
    for position in match_list_2: 
        if position[2] >= 0.00:  
            # Add to the pdb sequences
            pdb_seqs[0] = pdb_seqs[0] + aa_dict[position[0][0:3]]
            pdb_seqs[1] = pdb_seqs[1] + aa_dict[position[1][0:3]]

            # Check region to decide where to add it
            if position[2] >= 0.75:
                # Add to interfaces
                only_interfaces[0] = only_interfaces[0] + aa_dict[position[0][0:3]]
                only_interfaces[1] = only_interfaces[1] + aa_dict[position[1][0:3]]
            else:
                only_non_interfaces[0] = only_non_interfaces[0] + aa_dict[position[0][0:3]]
                only_non_interfaces[1] = only_non_interfaces[1] + aa_dict[position[1][0:3]]

    # I just need to save these sequences as records and write them
    # PDB seqs
    record_1 = SeqRecord(seq = Seq(pdb_seqs[0]), id = paralog_ID)
    record_2 = SeqRecord(seq = Seq(pdb_seqs[1]), id = paralog_ID_2)
    records = [record_1, record_2]
    
    out_pdb = os.path.join(output_path_010_only_PDB_positions, P1 + '_' + P2 + '_only_pdb_positions.fasta')
    
    SeqIO.write(records, out_pdb, 'fasta')

    # Only interfaces
    record_1 = SeqRecord(seq = Seq(only_interfaces[0]), id = paralog_ID)
    record_2 = SeqRecord(seq = Seq(only_interfaces[1]), id = paralog_ID_2)
    records = [record_1, record_2]
    
    out_interfaces = os.path.join(output_path_011_only_interfaces, P1 + '_' + P2 + '_only_interfaces.fasta')
    
    SeqIO.write(records, out_interfaces, 'fasta')

    # Only non-interfaces
    record_1 = SeqRecord(seq = Seq(only_non_interfaces[0]), id = paralog_ID)
    record_2 = SeqRecord(seq = Seq(only_non_interfaces[1]), id = paralog_ID_2)
    records = [record_1, record_2]
    
    out_non_interfaces = os.path.join(output_path_012_only_non_interfaces, P1 + '_' + P2 + '_only_non_interfaces.fasta')
    
    SeqIO.write(records, out_non_interfaces, 'fasta')
    
    return [out_pdb, out_interfaces, out_non_interfaces]

# %% [markdown]
# This is the block that gets sequence identities.

# %%
handle = open(integrated_table_file, 'r')
reader = csv.reader(handle, delimiter = '\t')

new_table = open(output_path + "/Paralogs_sequence_identities_dist_2019-06-19.txt", 'w')
new_table_writer = csv.writer(new_table, delimiter = '\t')

integrated_table_file = output_path + '/paralogs_PDB_structures_best_structures_best_isoforms_over50.txt'

headers = reader.next()
headers = headers + ["Compared_interface", "Full_sequence_identity", "PDB_sequence_identity", "Interface_sequence_identity", "Non_interface_sequence_identity", "Same_phylome"]
new_table_writer.writerow(headers)

distance_interface_path = output_006_dist_interfaces
interface_dict_path = output_007_interface_dict

missing_phylomes = OrderedDict()
missing_phylomeDB_IDs = OrderedDict()

# Loop through the lines
for line in reader:
    P1 = line[0]
    P2 = line[1]
    
    # Get the PDB files I need for that pair using the structure dictionary
    for complex_type, structure in paralogs2structures[(P1, P2)].items():
        
        # Get the PDB file that corresponds to this complex
        pdb_file = distance_interface_path + 'dist_regions_' + structure[0:4] + '.pdb' 

        print pdb_file
        print P1, P2
        bool_missing = False
        
        # Parse the interface dictionary if it is a HET
        if complex_type == 'HET':
            # Retrieve regions from the PDB file
            pdb_dict, start_dict, end_dict, pdb_sequence_dict = region_parser(pdb_file, aa_dict)
            
            # Run first with the first paralog
            paralog_ID = P1
            paralog_ID_2 = P2
            
            # Get the phylomeDB IDs based on the gene IDs
            gene_1 = isoform_to_gene_dict[paralog_ID]
            gene_2 = isoform_to_gene_dict[paralog_ID_2]
            
            phylo_ID = systematic2phylomeDB.get(gene_1, -1)
            phylo_ID_2 = systematic2phylomeDB.get(gene_2, -1)            
            
            if phylo_ID == -1:
                missing_phylomeDB_IDs[gene_1] = 1
                bool_missing = True
            elif not os.path.exists(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta')):
                missing_phylomes[gene_1] = phylo_ID
                bool_missing = True
            
            if bool_missing:
                # Use pairwise alignments
                record_1 = proteome_dict[paralog_ID]
                record_2 = proteome_dict[paralog_ID_2]
                
                phylome_dict = OrderedDict()
                phylome_dict[paralog_ID] = record_1
                phylome_dict[paralog_ID_2] = record_2
                
                record_list = []
                record_list.append(record_1)
                record_list.append(record_2)
                
                full_region_dict, match_list = first_round_alignments2(phylome_dict, paralog_ID, paralog_ID, alignment_dict, chain_dict)

                # Write the records and align
                outpath = os.path.join(output_path_009_phylo_PDB_aln, P1 + '_' + P2 + '.fasta')

                SeqIO.write(record_list, outpath, 'fasta')
                pair_align_dict = align_seqs(outpath)

                final_pair_dict = OrderedDict()

                for key, value in pair_align_dict.items():
                    if key in (paralog_ID, paralog_ID_2):
                        final_pair_dict[key] = value

                out_files = save_final_sequences2(final_pair_dict, full_region_dict, paralog_ID_2, paralog_ID, aa2three_letter)

                # Finally, we can read sequence similarity
                full_seq_ident = percentage_identity2(final_pair_dict)
                PDB_seq_ident = percentage_identity(in_file = out_files[0])
                interface_seq_ident = percentage_identity(in_file = out_files[1])
                non_interface_seq_ident = percentage_identity(in_file = out_files[2])

                # Check percentage identity
                print 'Full sequence identity:', full_seq_ident
                print "Whole PDB structure:", PDB_seq_ident
                print "Only interfaces:", interface_seq_ident
                print "Only non-interfaces:", non_interface_seq_ident
                print '---------'
                
                same_phylome = 0
                bool_missing = False
                new_table_writer.writerow(line + ["HET_P1", full_seq_ident, PDB_seq_ident, interface_seq_ident, non_interface_seq_ident, same_phylome])
            
            else:
                phylome_dict = fasta2dict(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta'))

                # Check if P2 is in this phylome
                if phylo_ID_2 == -1:
                    same_phylome = 0
                elif type(phylome_dict.get(phylo_ID_2, -1)) == SeqRecord:
                    same_phylome = 1
                else:
                    same_phylome = 0
                    
                record_list = fasta2list(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta'))

                # Add the reference sequence for the first paralog's isoform
                record_1 = proteome_dict[paralog_ID]
                record_list.append(record_1)
                phylome_dict[paralog_ID] = record_1

                # Add the second paralog's isoform to the phylome
                record_2 = proteome_dict[paralog_ID_2]
                record_list.append(record_2)
                phylome_dict[paralog_ID_2] = record_2

                full_region_dict, match_list = first_round_alignments2(phylome_dict, paralog_ID, paralog_ID, alignment_dict, chain_dict)

                # Write the records and align
                outpath = os.path.join(output_path_009_phylo_PDB_aln, P1 + '_' + P2 + '.fasta')

                SeqIO.write(record_list, outpath, 'fasta')
                pair_align_dict = align_seqs(outpath)

                final_pair_dict = OrderedDict()

                for key, value in pair_align_dict.items():
                    if key in (paralog_ID, paralog_ID_2):
                        final_pair_dict[key] = value


                out_files = save_final_sequences2(final_pair_dict, full_region_dict, paralog_ID_2, paralog_ID, aa2three_letter)

                # Finally, we can read sequence similarity
                full_seq_ident = percentage_identity2(final_pair_dict)
                PDB_seq_ident = percentage_identity(in_file = out_files[0])
                interface_seq_ident = percentage_identity(in_file = out_files[1])
                non_interface_seq_ident = percentage_identity(in_file = out_files[2])

                # Check percentage identity
                print 'Full sequence identity:', full_seq_ident
                print "Whole PDB structure:", PDB_seq_ident
                print "Only interfaces:", interface_seq_ident
                print "Only non-interfaces:", non_interface_seq_ident
                print '---------'

                new_table_writer.writerow(line + ["HET_P1", full_seq_ident, PDB_seq_ident, interface_seq_ident, non_interface_seq_ident, same_phylome])
            
            # Run with the second one
            paralog_ID = P2
            paralog_ID_2 = P1
            
            # Get the phylomeDB IDs based on the gene IDs
            gene_1 = isoform_to_gene_dict[paralog_ID]
            gene_2 = isoform_to_gene_dict[paralog_ID_2]
            
            phylo_ID = systematic2phylomeDB.get(gene_1, -1)
            phylo_ID_2 = systematic2phylomeDB.get(gene_2, -1)
            
            if phylo_ID == -1:
                missing_phylomeDB_IDs[gene_1] = 1
                bool_missing = True

            elif not os.path.exists(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta')):
                missing_phylomes[gene_1] = phylo_ID
                bool_missing = True
            
            if bool_missing:
                # Run the pairwise alignment
                record_1 = proteome_dict[paralog_ID]
                record_2 = proteome_dict[paralog_ID_2]
                
                phylome_dict = OrderedDict()
                phylome_dict[paralog_ID] = record_1
                phylome_dict[paralog_ID_2] = record_2
                
                record_list = []
                record_list.append(record_1)
                record_list.append(record_2)
                
                full_region_dict, match_list = first_round_alignments2(phylome_dict, paralog_ID, paralog_ID, alignment_dict, chain_dict)

                # Write the records and align
                outpath = os.path.join(output_path_009_phylo_PDB_aln, P1 + '_' + P2 + '.fasta')

                SeqIO.write(record_list, outpath, 'fasta')
                pair_align_dict = align_seqs(outpath)

                final_pair_dict = OrderedDict()

                for key, value in pair_align_dict.items():
                    if key in (paralog_ID, paralog_ID_2):
                        final_pair_dict[key] = value

                out_files = save_final_sequences2(final_pair_dict, full_region_dict, paralog_ID_2, paralog_ID, aa2three_letter)

                # Finally, we can read sequence similarity
                full_seq_ident = percentage_identity2(final_pair_dict)
                PDB_seq_ident = percentage_identity(in_file = out_files[0])
                interface_seq_ident = percentage_identity(in_file = out_files[1])
                non_interface_seq_ident = percentage_identity(in_file = out_files[2])

                # Check percentage identity
                print 'Full sequence identity:', full_seq_ident
                print "Whole PDB structure:", PDB_seq_ident
                print "Only interfaces:", interface_seq_ident
                print "Only non-interfaces:", non_interface_seq_ident
                print '---------'
                
                same_phylome = 0
                bool_missing = False
                new_table_writer.writerow(line + ["HET_P2", full_seq_ident, PDB_seq_ident, interface_seq_ident, non_interface_seq_ident, same_phylome])
            
            else: 
                phylome_dict = fasta2dict(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta'))

                # Check if P2 is in this phylome
                if phylo_ID_2 == -1:
                    same_phylome = 0
                elif type(phylome_dict.get(phylo_ID_2, -1)) == SeqRecord:
                    same_phylome = 1
                else:
                    same_phylome = 0
                
                record_list = fasta2list(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta'))

                # Add the reference sequence for the first paralog's isoform
                record_1 = proteome_dict[paralog_ID]
                record_list.append(record_1)
                phylome_dict[paralog_ID] = record_1

                # Add the second paralog's isoform to the phylome
                record_2 = proteome_dict[paralog_ID_2]
                record_list.append(record_2)
                phylome_dict[paralog_ID_2] = record_2

                # Here, I will find the matches between the PDB sequence and the isoform of the first paralog
                full_region_dict, match_list = first_round_alignments2(phylome_dict, paralog_ID, paralog_ID, alignment_dict, chain_dict)

                # Write the records and align
                outpath = os.path.join(output_path_009_phylo_PDB_aln, P1 + '_' + P2 + '.fasta')

                SeqIO.write(record_list, outpath, 'fasta')
                pair_align_dict = align_seqs(outpath)

                final_pair_dict = OrderedDict()

                for key, value in pair_align_dict.items():
                    if key in (paralog_ID, paralog_ID_2):
                        final_pair_dict[key] = value

                out_files = save_final_sequences2(final_pair_dict, full_region_dict, paralog_ID_2, paralog_ID, aa2three_letter)

                # Finally, we can read sequence similarity
                full_seq_ident = percentage_identity2(final_pair_dict)
                PDB_seq_ident = percentage_identity(in_file = out_files[0])
                interface_seq_ident = percentage_identity(in_file = out_files[1])
                non_interface_seq_ident = percentage_identity(in_file = out_files[2])

                # Check percentage identity
                print 'Full sequence identity:', full_seq_ident
                print "Whole PDB structure:", PDB_seq_ident
                print "Only interfaces:", interface_seq_ident
                print "Only non-interfaces:", non_interface_seq_ident
                print '---------'
                new_table_writer.writerow(line + ["HET_P2", full_seq_ident, PDB_seq_ident, interface_seq_ident, non_interface_seq_ident, same_phylome])

        else:
            # Retrieve regions from the PDB file
            pdb_dict, start_dict, end_dict, pdb_sequence_dict = region_parser(pdb_file, aa_dict)
            
            # As these are HM, I can get the sequence from any of them
            pdb_sequence = pdb_sequence_dict.values()[0]
            
            if complex_type == 'P1_HM':  
                paralog_ID = P1
                paralog_ID_2 = P2
                print 'P1_HM'
            elif complex_type == 'P2_HM':
                paralog_ID = P2
                paralog_ID_2 = P1
                print 'P2_HM'
            
            # Get the phylomeDB IDs based on the gene IDs
            gene_1 = isoform_to_gene_dict[paralog_ID]
            gene_2 = isoform_to_gene_dict[paralog_ID_2]
            
            phylo_ID = systematic2phylomeDB.get(gene_1, -1)
            phylo_ID_2 = systematic2phylomeDB.get(gene_2, -1)
            
            if phylo_ID == -1:
                missing_phylomeDB_IDs[gene_1] = 1
                bool_missing = True
                
            elif not os.path.exists(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta')):
                missing_phylomes[gene_1] = phylo_ID
                bool_missing = True
            
            if bool_missing:
                # Run the pairwise alignment
                record_1 = proteome_dict[paralog_ID]
                record_2 = proteome_dict[paralog_ID_2]
                
                phylome_dict = OrderedDict()
                phylome_dict[paralog_ID] = record_1
                phylome_dict[paralog_ID_2] = record_2
                
                record_list = []
                record_list.append(record_1)
                record_list.append(record_2)
                
                full_region_dict, match_list = first_round_alignments2(phylome_dict, paralog_ID, paralog_ID, alignment_dict, chain_dict)

                # Write the records and align
                outpath = os.path.join(output_path_009_phylo_PDB_aln, P1 + '_' + P2 + '.fasta')

                SeqIO.write(record_list, outpath, 'fasta')
                pair_align_dict = align_seqs(outpath)

                final_pair_dict = OrderedDict()

                for key, value in pair_align_dict.items():
                    if key in (paralog_ID, paralog_ID_2):
                        final_pair_dict[key] = value

                out_files = save_final_sequences2(final_pair_dict, full_region_dict, paralog_ID_2, paralog_ID, aa2three_letter)

                # Finally, we can read sequence similarity
                full_seq_ident = percentage_identity2(final_pair_dict)
                PDB_seq_ident = percentage_identity(in_file = out_files[0])
                interface_seq_ident = percentage_identity(in_file = out_files[1])
                non_interface_seq_ident = percentage_identity(in_file = out_files[2])

                # Check percentage identity
                print 'Full sequence identity:', full_seq_ident
                print "Whole PDB structure:", PDB_seq_ident
                print "Only interfaces:", interface_seq_ident
                print "Only non-interfaces:", non_interface_seq_ident
                print '---------'
                
                same_phylome = 0
                bool_missing = False
                new_table_writer.writerow(line + [complex_type, full_seq_ident, PDB_seq_ident, interface_seq_ident, non_interface_seq_ident, same_phylome])
            
            else:
            
                phylome_dict = fasta2dict(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta'))

                # Check if P2 is in this phylome
                if phylo_ID_2 == -1:
                    same_phylome = 0
                elif type(phylome_dict.get(phylo_ID_2, -1)) == SeqRecord:
                    same_phylome = 1
                else:
                    same_phylome = 0
                
                record_list = fasta2list(os.path.join(phylomedb_path, phylo_ID + '.raw.fasta'))

                # Add the reference sequence for the first paralog's isoform
                record_1 = proteome_dict[paralog_ID]
                record_list.append(record_1)
                phylome_dict[paralog_ID] = record_1

                # Add the second paralog's isoform to the phylome
                record_2 = proteome_dict[paralog_ID_2]
                record_list.append(record_2)
                phylome_dict[paralog_ID_2] = record_2

                full_region_dict, match_list = first_round_alignments2(phylome_dict, paralog_ID, paralog_ID, alignment_dict, chain_dict)

                # Write the records and align
                outpath = os.path.join(output_path_009_phylo_PDB_aln, P1 + '_' + P2 + '.fasta')

                SeqIO.write(record_list, outpath, 'fasta')
                pair_align_dict = align_seqs(outpath)

                final_pair_dict = OrderedDict()

                for key, value in pair_align_dict.items():
                    if key in (paralog_ID, paralog_ID_2):
                        final_pair_dict[key] = value

                out_files = save_final_sequences2(final_pair_dict, full_region_dict, paralog_ID_2, paralog_ID, aa2three_letter)

                # Finally, we can read sequence similarity
                full_seq_ident = percentage_identity2(final_pair_dict)
                PDB_seq_ident = percentage_identity(in_file = out_files[0])
                interface_seq_ident = percentage_identity(in_file = out_files[1])
                non_interface_seq_ident = percentage_identity(in_file = out_files[2])

                # Check percentage identity
                print 'Full sequence identity:', full_seq_ident
                print "Whole PDB structure:", PDB_seq_ident
                print "Only interfaces:", interface_seq_ident
                print "Only non-interfaces:", non_interface_seq_ident
                print '---------'
                new_table_writer.writerow(line + [complex_type, full_seq_ident, PDB_seq_ident, interface_seq_ident, non_interface_seq_ident, same_phylome])

handle.close()
new_table.close()
# Out:
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5t68.pdb
# ENSP00000264972.5 ENSP00000364907.4
# P2_HM
# Full sequence identity: 50.99
# Whole PDB structure: 62.88
# Only interfaces: 46.67
# Only non-interfaces: 64.96
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5t68.pdb
# ENSP00000364907.4 ENSP00000400475.2
# P1_HM
# Full sequence identity: 26.34
# Whole PDB structure: 62.88
# Only interfaces: 46.67
# Only non-interfaces: 64.96
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000497767.1
# P1_HM
# Full sequence identity: 61.0
# Whole PDB structure: 72.27
# Only interfaces: 78.99
# Only non-interfaces: 68.32
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000363988.4 ENSP00000457468.2
# P2_HM
# Full sequence identity: 61.0
# Whole PDB structure: 72.27
# Only interfaces: 78.99
# Only non-interfaces: 68.32
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000497990.1
# P1_HM
# Full sequence identity: 61.0
# Whole PDB structure: 72.27
# Only interfaces: 78.99
# Only non-interfaces: 68.32
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000497731.1
# P1_HM
# Full sequence identity: 61.0
# Whole PDB structure: 72.27
# Only interfaces: 78.99
# Only non-interfaces: 68.32
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000497216.1
# P1_HM
# Full sequence identity: 58.37
# Whole PDB structure: 72.38
# Only interfaces: 78.99
# Only non-interfaces: 68.37
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000497985.1
# P1_HM
# Full sequence identity: 11.48
# Whole PDB structure: 64.52
# Only interfaces: 81.25
# Only non-interfaces: 58.7
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000481363.1
# P1_HM
# Full sequence identity: 53.59
# Whole PDB structure: 72.24
# Only interfaces: 78.99
# Only non-interfaces: 67.78
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000378729.3 ENSP00000457468.2
# P2_HM
# Full sequence identity: 64.59
# Whole PDB structure: 83.45
# Only interfaces: 88.99
# Only non-interfaces: 80.21
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1xfb.pdb
# ENSP00000378731.2 ENSP00000457468.2
# P1_HM
# Full sequence identity: 71.29
# Whole PDB structure: 83.33
# Only interfaces: 91.43
# Only non-interfaces: 79.75
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000378731.2 ENSP00000457468.2
# P2_HM
# Full sequence identity: 71.29
# Whole PDB structure: 84.88
# Only interfaces: 90.16
# Only non-interfaces: 81.68
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000226253.4 ENSP00000457468.2
# P2_HM
# Full sequence identity: 71.29
# Whole PDB structure: 84.88
# Only interfaces: 90.16
# Only non-interfaces: 81.68
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000463174.2
# P1_HM
# Full sequence identity: 35.89
# Whole PDB structure: 84.12
# Only interfaces: 88.73
# Only non-interfaces: 80.81
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000462674.1
# P1_HM
# Full sequence identity: 34.69
# Whole PDB structure: 83.64
# Only interfaces: 87.88
# Only non-interfaces: 80.81
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000465623.1
# P1_HM
# Full sequence identity: 26.56
# Whole PDB structure: 83.33
# Only interfaces: 91.3
# Only non-interfaces: 78.75
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000398976.1 ENSP00000457468.2
# P2_HM
# Full sequence identity: 29.19
# Whole PDB structure: 82.73
# Only interfaces: 88.37
# Only non-interfaces: 80.21
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5ky6.pdb
# ENSP00000457468.2 ENSP00000463118.1
# P1_HM
# Full sequence identity: 22.73
# Whole PDB structure: 78.57
# Only interfaces: 84.38
# Only non-interfaces: 76.25
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000420756.1
# P1_HM
# Full sequence identity: 28.54
# Whole PDB structure: 78.77
# Only interfaces: 78.79
# Only non-interfaces: 78.76
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000418742.1
# P1_HM
# Full sequence identity: 26.68
# Whole PDB structure: 78.77
# Only interfaces: 78.79
# Only non-interfaces: 78.76
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000399400.2
# P1_HM
# Full sequence identity: 72.26
# Whole PDB structure: 81.94
# Only interfaces: 78.74
# Only non-interfaces: 83.93
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000345096.6
# P1_HM
# Full sequence identity: 72.12
# Whole PDB structure: 85.46
# Only interfaces: 85.06
# Only non-interfaces: 85.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000420803.1
# P1_HM
# Full sequence identity: 79.38
# Whole PDB structure: 84.85
# Only interfaces: 85.06
# Only non-interfaces: 84.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000346219.5
# P1_HM
# Full sequence identity: 73.34
# Whole PDB structure: 85.46
# Only interfaces: 85.06
# Only non-interfaces: 85.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000265385.8 ENSP00000321584.4
# P2_HM
# Full sequence identity: 76.73
# Whole PDB structure: 85.46
# Only interfaces: 85.06
# Only non-interfaces: 85.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000417296.1
# P1_HM
# Full sequence identity: 83.85
# Whole PDB structure: 85.43
# Only interfaces: 85.06
# Only non-interfaces: 85.66
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000496892.1
# P1_HM
# Full sequence identity: 72.53
# Whole PDB structure: 84.74
# Only interfaces: 83.54
# Only non-interfaces: 85.45
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000420185.1
# P1_HM
# Full sequence identity: 83.07
# Whole PDB structure: 85.3
# Only interfaces: 85.06
# Only non-interfaces: 85.45
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000419609.1
# P1_HM
# Full sequence identity: 39.43
# Whole PDB structure: 79.48
# Only interfaces: 51.52
# Only non-interfaces: 84.18
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000418592.1
# P1_HM
# Full sequence identity: 21.32
# Whole PDB structure: 69.6
# Only interfaces: 51.52
# Only non-interfaces: 76.09
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000420469.1
# P1_HM
# Full sequence identity: 3.5
# Whole PDB structure: 25.4
# Only interfaces: 15.38
# Only non-interfaces: 28.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1nf7.pdb
# ENSP00000321584.4 ENSP00000486056.1
# P1_HM
# Full sequence identity: 83.85
# Whole PDB structure: 85.43
# Only interfaces: 85.06
# Only non-interfaces: 85.66
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000270279.3
# P1_HM
# Full sequence identity: 24.32
# Whole PDB structure: 48.68
# Only interfaces: 43.59
# Only non-interfaces: 49.43
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000340250.4
# P1_HM
# Full sequence identity: 20.41
# Whole PDB structure: 43.75
# Only interfaces: 43.59
# Only non-interfaces: 43.78
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000494162.1
# P1_HM
# Full sequence identity: 24.32
# Whole PDB structure: 48.68
# Only interfaces: 43.59
# Only non-interfaces: 49.43
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000495258.1
# P1_HM
# Full sequence identity: 12.03
# Whole PDB structure: 59.89
# Only interfaces: 54.17
# Only non-interfaces: 60.76
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000377598.4
# P1_HM
# Full sequence identity: 47.69
# Whole PDB structure: 83.44
# Only interfaces: 89.74
# Only non-interfaces: 82.51
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000496297.1
# P1_HM
# Full sequence identity: 19.1
# Whole PDB structure: 77.1
# Only interfaces: 90.91
# Only non-interfaces: 75.52
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000264122.4
# P1_HM
# Full sequence identity: 47.69
# Whole PDB structure: 83.44
# Only interfaces: 89.74
# Only non-interfaces: 82.51
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000494383.1
# P1_HM
# Full sequence identity: 46.47
# Whole PDB structure: 83.44
# Only interfaces: 89.74
# Only non-interfaces: 82.51
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000496708.1
# P1_HM
# Full sequence identity: 8.78
# Whole PDB structure: 68.93
# Only interfaces: 100.0
# Only non-interfaces: 66.32
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000494262.1
# P1_HM
# Full sequence identity: 6.5
# Whole PDB structure: 35.29
# Only interfaces: 40.0
# Only non-interfaces: 34.48
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000496761.1
# P1_HM
# Full sequence identity: 46.47
# Whole PDB structure: 83.44
# Only interfaces: 89.74
# Only non-interfaces: 82.51
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000496352.1
# P1_HM
# Full sequence identity: 45.19
# Whole PDB structure: 82.89
# Only interfaces: 89.74
# Only non-interfaces: 81.89
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000384816.1
# P1_HM
# Full sequence identity: 45.97
# Whole PDB structure: 83.44
# Only interfaces: 89.74
# Only non-interfaces: 82.51
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000384938.1
# P1_HM
# Full sequence identity: 47.78
# Whole PDB structure: 83.44
# Only interfaces: 89.74
# Only non-interfaces: 82.51
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000400949.2
# P1_HM
# Full sequence identity: 16.36
# Whole PDB structure: 78.21
# Only interfaces: 100.0
# Only non-interfaces: 75.63
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000494989.1
# P1_HM
# Full sequence identity: 10.79
# Whole PDB structure: 76.8
# Only interfaces: 100.0
# Only non-interfaces: 75.21
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000409750.2
# P1_HM
# Full sequence identity: 10.97
# Whole PDB structure: 73.6
# Only interfaces: 100.0
# Only non-interfaces: 71.79
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000393906.2
# P1_HM
# Full sequence identity: 9.44
# Whole PDB structure: 72.64
# Only interfaces: 100.0
# Only non-interfaces: 70.41
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000495754.1
# P1_HM
# Full sequence identity: 9.44
# Whole PDB structure: 72.64
# Only interfaces: 100.0
# Only non-interfaces: 70.41
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1b47.pdb
# ENSP00000264033.3 ENSP00000499037.1
# P1_HM
# Full sequence identity: 46.74
# Whole PDB structure: 82.89
# Only interfaces: 89.74
# Only non-interfaces: 81.89
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000370912.3 ENSP00000483570.1
# P2_HM
# Full sequence identity: 50.0
# Whole PDB structure: 62.36
# Only interfaces: 68.18
# Only non-interfaces: 61.83
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000424567.1 ENSP00000483570.1
# P2_HM
# Full sequence identity: 7.65
# Whole PDB structure: 33.33
# Only interfaces: 42.86
# Only non-interfaces: 28.57
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000424365.1 ENSP00000483570.1
# P2_HM
# Full sequence identity: 4.91
# Whole PDB structure: 66.67
# Only interfaces: 54.55
# Only non-interfaces: 70.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000264316.4 ENSP00000483570.1
# P2_HM
# Full sequence identity: 40.52
# Whole PDB structure: 60.46
# Only interfaces: 63.64
# Only non-interfaces: 60.17
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000422139.1 ENSP00000483570.1
# P2_HM
# Full sequence identity: 6.64
# Whole PDB structure: 56.1
# Only interfaces: 0
# Only non-interfaces: 56.1
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000423481.1 ENSP00000483570.1
# P2_HM
# Full sequence identity: 15.15
# Whole PDB structure: 57.69
# Only interfaces: 100.0
# Only non-interfaces: 56.74
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000424070.1 ENSP00000483570.1
# P2_HM
# Full sequence identity: 3.9
# Whole PDB structure: 56.25
# Only interfaces: 0
# Only non-interfaces: 56.25
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5j87.pdb
# ENSP00000422798.1 ENSP00000483570.1
# P2_HM
# Full sequence identity: 9.05
# Whole PDB structure: 0
# Only interfaces: 0
# Only non-interfaces: 0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000295025.7 ENSP00000384273.3
# P2_HM
# Full sequence identity: 33.23
# Whole PDB structure: 69.81
# Only interfaces: 92.59
# Only non-interfaces: 62.03
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000377989.3 ENSP00000384273.3
# P2_HM
# Full sequence identity: 35.32
# Whole PDB structure: 69.81
# Only interfaces: 92.59
# Only non-interfaces: 62.03
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000384273.3 ENSP00000496299.1
# P1_HM
# Full sequence identity: 5.81
# Whole PDB structure: 13.33
# Only interfaces: 0
# Only non-interfaces: 13.33
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000221452.7 ENSP00000384273.3
# P2_HM
# Full sequence identity: 26.68
# Whole PDB structure: 57.01
# Only interfaces: 77.78
# Only non-interfaces: 50.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000384273.3 ENSP00000427348.1
# P1_HM
# Full sequence identity: 1.77
# Whole PDB structure: 0
# Only interfaces: 0
# Only non-interfaces: 0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000384273.3 ENSP00000423287.1
# P1_HM
# Full sequence identity: 25.81
# Whole PDB structure: 57.01
# Only interfaces: 77.78
# Only non-interfaces: 50.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000384273.3 ENSP00000468460.1
# P1_HM
# Full sequence identity: 4.75
# Whole PDB structure: 50.0
# Only interfaces: 0
# Only non-interfaces: 50.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1my5.pdb
# ENSP00000384273.3 ENSP00000485826.1
# P1_HM
# Full sequence identity: 26.68
# Whole PDB structure: 57.01
# Only interfaces: 77.78
# Only non-interfaces: 50.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000428924.1
# P1_HM
# Full sequence identity: 59.12
# Whole PDB structure: 66.35
# Only interfaces: 62.5
# Only non-interfaces: 67.05
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000428424.1
# P1_HM
# Full sequence identity: 60.0
# Whole PDB structure: 66.35
# Only interfaces: 62.5
# Only non-interfaces: 67.05
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000428313.1
# P1_HM
# Full sequence identity: 11.15
# Whole PDB structure: 73.08
# Only interfaces: 83.33
# Only non-interfaces: 70.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000365022.2
# P1_HM
# Full sequence identity: 59.96
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000486627.1
# P1_HM
# Full sequence identity: 61.95
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000420457.1
# P1_HM
# Full sequence identity: 4.45
# Whole PDB structure: 60.0
# Only interfaces: 0
# Only non-interfaces: 60.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000262651.3 ENSP00000328213.4
# P2_HM
# Full sequence identity: 2.41
# Whole PDB structure: 50.0
# Only interfaces: 0
# Only non-interfaces: 50.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000429848.1
# P1_HM
# Full sequence identity: 61.95
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000427757.1
# P1_HM
# Full sequence identity: 62.11
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000365012.2
# P1_HM
# Full sequence identity: 59.82
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000441169.1
# P1_HM
# Full sequence identity: 61.95
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000444986.3
# P1_HM
# Full sequence identity: 60.0
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1bhh.pdb
# ENSP00000328213.4 ENSP00000491964.1
# P1_HM
# Full sequence identity: 60.14
# Whole PDB structure: 70.19
# Only interfaces: 62.5
# Only non-interfaces: 71.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4ju5.pdb
# ENSP00000219406.6 ENSP00000327801.4
# P2_HM
# Full sequence identity: 44.16
# Whole PDB structure: 41.03
# Only interfaces: 46.58
# Only non-interfaces: 37.7
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4ju5.pdb
# ENSP00000327801.4 ENSP00000384410.1
# P1_HM
# Full sequence identity: 44.28
# Whole PDB structure: 41.03
# Only interfaces: 46.58
# Only non-interfaces: 37.7
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4ju5.pdb
# ENSP00000327801.4 ENSP00000392277.1
# P1_HM
# Full sequence identity: 19.08
# Whole PDB structure: 42.11
# Only interfaces: 0.0
# Only non-interfaces: 42.86
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4ju5.pdb
# ENSP00000327801.4 ENSP00000405081.1
# P1_HM
# Full sequence identity: 15.13
# Whole PDB structure: 66.67
# Only interfaces: 100.0
# Only non-interfaces: 50.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4ju5.pdb
# ENSP00000305465.4 ENSP00000327801.4
# P2_HM
# Full sequence identity: 27.43
# Whole PDB structure: 27.5
# Only interfaces: 31.08
# Only non-interfaces: 25.4
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4ju5.pdb
# ENSP00000327801.4 ENSP00000459161.1
# P1_HM
# Full sequence identity: 8.4
# Whole PDB structure: 25.53
# Only interfaces: 27.59
# Only non-interfaces: 22.22
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4acq.pdb
# ENSP00000261336.2 ENSP00000323929.7
# P2_HM
# Full sequence identity: 67.85
# Whole PDB structure: 73.4
# Only interfaces: 57.14
# Only non-interfaces: 75.57
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4acq.pdb
# ENSP00000323929.7 ENSP00000440811.1
# P1_HM
# Full sequence identity: 6.65
# Whole PDB structure: 72.03
# Only interfaces: 66.67
# Only non-interfaces: 73.2
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000352929.3 ENSP00000381531.5
# P2_HM
# Full sequence identity: 76.24
# Whole PDB structure: 96.92
# Only interfaces: 100.0
# Only non-interfaces: 96.34
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000400494.1
# P1_HM
# Full sequence identity: 8.88
# Whole PDB structure: 25.0
# Only interfaces: 20.0
# Only non-interfaces: 28.57
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000403610.1
# P1_HM
# Full sequence identity: 17.24
# Whole PDB structure: 92.59
# Only interfaces: 0
# Only non-interfaces: 92.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000384074.1
# P1_HM
# Full sequence identity: 76.24
# Whole PDB structure: 96.92
# Only interfaces: 100.0
# Only non-interfaces: 96.34
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000412194.1
# P1_HM
# Full sequence identity: 4.42
# Whole PDB structure: 18.48
# Only interfaces: 9.09
# Only non-interfaces: 21.43
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000407235.2
# P1_HM
# Full sequence identity: 67.98
# Whole PDB structure: 96.23
# Only interfaces: 100.0
# Only non-interfaces: 95.53
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000384426.3
# P1_HM
# Full sequence identity: 67.37
# Whole PDB structure: 97.22
# Only interfaces: 100.0
# Only non-interfaces: 96.69
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000397460.1
# P1_HM
# Full sequence identity: 3.98
# Whole PDB structure: 17.44
# Only interfaces: 26.32
# Only non-interfaces: 14.93
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000403057.1
# P1_HM
# Full sequence identity: 55.04
# Whole PDB structure: 97.83
# Only interfaces: 100.0
# Only non-interfaces: 97.28
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000381531.5 ENSP00000412335.1
# P1_HM
# Full sequence identity: 51.05
# Whole PDB structure: 96.79
# Only interfaces: 100.0
# Only non-interfaces: 96.53
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1cki.pdb
# ENSP00000380044.1 ENSP00000381531.5
# P2_HM
# Full sequence identity: 76.24
# Whole PDB structure: 96.92
# Only interfaces: 100.0
# Only non-interfaces: 96.34
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4a9z.pdb
# ENSP00000264731.3 ENSP00000367545.4
# P1_HM
# Full sequence identity: 50.5
# Whole PDB structure: 57.14
# Only interfaces: 57.14
# Only non-interfaces: 0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3cvf.pdb
# ENSP00000334382.6 ENSP00000439937.1
# P2_HM
# Full sequence identity: 49.86
# Whole PDB structure: 41.18
# Only interfaces: 41.18
# Only non-interfaces: 0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000302625.5
# P1_HM
# Full sequence identity: 40.58
# Whole PDB structure: 61.54
# Only interfaces: 62.0
# Only non-interfaces: 61.29
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000364854.5
# P1_HM
# Full sequence identity: 39.62
# Whole PDB structure: 61.54
# Only interfaces: 62.0
# Only non-interfaces: 61.29
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000464264.1
# P1_HM
# Full sequence identity: 16.34
# Whole PDB structure: 61.54
# Only interfaces: 62.0
# Only non-interfaces: 61.29
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000463761.1
# P1_HM
# Full sequence identity: 12.51
# Whole PDB structure: 61.9
# Only interfaces: 67.57
# Only non-interfaces: 59.55
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000463192.1
# P1_HM
# Full sequence identity: 12.51
# Whole PDB structure: 62.4
# Only interfaces: 67.57
# Only non-interfaces: 60.23
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000441151.2
# P1_HM
# Full sequence identity: 9.27
# Whole PDB structure: 60.71
# Only interfaces: 67.57
# Only non-interfaces: 55.32
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000478916.1
# P1_HM
# Full sequence identity: 39.62
# Whole PDB structure: 61.54
# Only interfaces: 62.0
# Only non-interfaces: 61.29
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1dk8.pdb
# ENSP00000262320.3 ENSP00000481191.1
# P1_HM
# Full sequence identity: 9.15
# Whole PDB structure: 61.02
# Only interfaces: 75.0
# Only non-interfaces: 51.43
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000356707.2 ENSP00000362014.3
# P2_HM
# Full sequence identity: 54.63
# Whole PDB structure: 88.03
# Only interfaces: 93.55
# Only non-interfaces: 86.64
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000347457.5 ENSP00000362014.3
# P2_HM
# Full sequence identity: 78.71
# Whole PDB structure: 87.39
# Only interfaces: 93.55
# Only non-interfaces: 85.98
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000486701.1
# P1_HM
# Full sequence identity: 79.11
# Whole PDB structure: 86.49
# Only interfaces: 93.55
# Only non-interfaces: 84.87
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000356705.1 ENSP00000362014.3
# P2_HM
# Full sequence identity: 79.13
# Whole PDB structure: 87.39
# Only interfaces: 93.55
# Only non-interfaces: 85.98
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000429701.1
# P1_HM
# Full sequence identity: 62.15
# Whole PDB structure: 87.78
# Only interfaces: 93.55
# Only non-interfaces: 86.35
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000429416.1
# P1_HM
# Full sequence identity: 43.52
# Whole PDB structure: 87.32
# Only interfaces: 92.31
# Only non-interfaces: 85.62
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000429165.1
# P1_HM
# Full sequence identity: 17.98
# Whole PDB structure: 79.17
# Only interfaces: 0
# Only non-interfaces: 79.17
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000468734.1
# P1_HM
# Full sequence identity: 78.48
# Whole PDB structure: 86.79
# Only interfaces: 91.94
# Only non-interfaces: 85.61
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000352721.6 ENSP00000362014.3
# P2_HM
# Full sequence identity: 78.28
# Whole PDB structure: 86.79
# Only interfaces: 91.94
# Only non-interfaces: 85.61
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000373905.3
# P1_HM
# Full sequence identity: 77.83
# Whole PDB structure: 86.79
# Only interfaces: 91.94
# Only non-interfaces: 85.61
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000347890.6 ENSP00000362014.3
# P2_HM
# Full sequence identity: 78.62
# Whole PDB structure: 86.79
# Only interfaces: 91.94
# Only non-interfaces: 85.61
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000386192.3
# P1_HM
# Full sequence identity: 77.49
# Whole PDB structure: 86.79
# Only interfaces: 91.94
# Only non-interfaces: 85.61
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000467430.1
# P1_HM
# Full sequence identity: 4.51
# Whole PDB structure: 79.17
# Only interfaces: 85.0
# Only non-interfaces: 75.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000466603.2
# P1_HM
# Full sequence identity: 26.32
# Whole PDB structure: 85.92
# Only interfaces: 0
# Only non-interfaces: 85.92
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000466914.1
# P1_HM
# Full sequence identity: 9.92
# Whole PDB structure: 91.67
# Only interfaces: 0
# Only non-interfaces: 91.67
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2x2e.pdb
# ENSP00000362014.3 ENSP00000466621.1
# P1_HM
# Full sequence identity: 4.94
# Whole PDB structure: 43.24
# Only interfaces: 66.67
# Only non-interfaces: 41.18
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ef1.pdb
# ENSP00000338934.7 ENSP00000353408.5
# P2_HM
# Full sequence identity: 72.18
# Whole PDB structure: 85.12
# Only interfaces: 88.43
# Only non-interfaces: 82.74
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ef1.pdb
# ENSP00000353408.5 ENSP00000356042.3
# P1_HM
# Full sequence identity: 72.18
# Whole PDB structure: 85.12
# Only interfaces: 88.43
# Only non-interfaces: 82.74
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ef1.pdb
# ENSP00000353408.5 ENSP00000376016.5
# P1_HM
# Full sequence identity: 72.53
# Whole PDB structure: 85.12
# Only interfaces: 88.43
# Only non-interfaces: 82.74
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4yqu.pdb
# ENSP00000345023.1 ENSP00000358727.5
# P2_HM
# Full sequence identity: 63.79
# Whole PDB structure: 64.68
# Only interfaces: 75.56
# Only non-interfaces: 62.11
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4yqu.pdb
# ENSP00000358721.1 ENSP00000358727.5
# P2_HM
# Full sequence identity: 54.73
# Whole PDB structure: 63.33
# Only interfaces: 75.56
# Only non-interfaces: 60.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4yqu.pdb
# ENSP00000358727.5 ENSP00000390986.2
# P1_HM
# Full sequence identity: 59.5
# Whole PDB structure: 68.78
# Only interfaces: 75.56
# Only non-interfaces: 66.88
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1zs6.pdb
# ENSP00000219302.3 ENSP00000395605.1
# P1_HM
# Full sequence identity: 37.77
# Whole PDB structure: 57.89
# Only interfaces: 58.0
# Only non-interfaces: 57.69
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ehw.pdb
# ENSP00000219302.3 ENSP00000395605.1
# P2_HM
# Full sequence identity: 39.06
# Whole PDB structure: 62.14
# Only interfaces: 65.82
# Only non-interfaces: 57.38
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ehw.pdb
# ENSP00000395605.1 ENSP00000456160.1
# P1_HM
# Full sequence identity: 20.25
# Whole PDB structure: 43.84
# Only interfaces: 43.33
# Only non-interfaces: 46.15
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ehw.pdb
# ENSP00000395605.1 ENSP00000455271.1
# P1_HM
# Full sequence identity: 12.45
# Whole PDB structure: 60.0
# Only interfaces: 64.71
# Only non-interfaces: 45.45
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ehw.pdb
# ENSP00000395605.1 ENSP00000455435.1
# P1_HM
# Full sequence identity: 21.03
# Whole PDB structure: 64.0
# Only interfaces: 65.22
# Only non-interfaces: 62.07
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1ehw.pdb
# ENSP00000395605.1 ENSP00000454498.1
# P1_HM
# Full sequence identity: 13.3
# Whole PDB structure: 64.71
# Only interfaces: 72.0
# Only non-interfaces: 44.44
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3dds.pdb
# ENSP00000216392.7 ENSP00000216962.3
# P1_HM
# Full sequence identity: 81.11
# Whole PDB structure: 82.22
# Only interfaces: 95.05
# Only non-interfaces: 80.39
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5iko.pdb
# ENSP00000216392.7 ENSP00000216962.3
# P2_HM
# Full sequence identity: 81.11
# Whole PDB structure: 82.65
# Only interfaces: 86.29
# Only non-interfaces: 81.99
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3dds.pdb
# ENSP00000216392.7 ENSP00000395451.1
# P1_HM
# Full sequence identity: 21.49
# Whole PDB structure: 74.29
# Only interfaces: 61.54
# Only non-interfaces: 75.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1hvv.pdb
# ENSP00000215095.5 ENSP00000222812.3
# P2_HM
# Full sequence identity: 82.7
# Whole PDB structure: 92.54
# Only interfaces: 92.19
# Only non-interfaces: 100.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1hvv.pdb
# ENSP00000222812.3 ENSP00000455899.1
# P1_HM
# Full sequence identity: 77.51
# Whole PDB structure: 92.54
# Only interfaces: 92.19
# Only non-interfaces: 100.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1flk.pdb
# ENSP00000261464.5 ENSP00000454207.1
# P2_HM
# Full sequence identity: 40.31
# Whole PDB structure: 58.38
# Only interfaces: 45.83
# Only non-interfaces: 65.6
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1flk.pdb
# ENSP00000355971.3 ENSP00000454207.1
# P2_HM
# Full sequence identity: 40.31
# Whole PDB structure: 58.38
# Only interfaces: 45.83
# Only non-interfaces: 65.6
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_1flk.pdb
# ENSP00000336825.2 ENSP00000454207.1
# P2_HM
# Full sequence identity: 40.31
# Whole PDB structure: 58.38
# Only interfaces: 45.83
# Only non-interfaces: 65.6
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4cl7.pdb
# ENSP00000282397.4 ENSP00000495159.1
# P1_HM
# Full sequence identity: 41.15
# Whole PDB structure: 32.26
# Only interfaces: 16.67
# Only non-interfaces: 37.68
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3kvq.pdb
# ENSP00000282397.4 ENSP00000495159.1
# P2_HM
# Full sequence identity: 41.86
# Whole PDB structure: 39.02
# Only interfaces: 42.86
# Only non-interfaces: 37.7
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4cl7.pdb
# ENSP00000263923.4 ENSP00000282397.4
# P2_HM
# Full sequence identity: 41.15
# Whole PDB structure: 32.26
# Only interfaces: 16.67
# Only non-interfaces: 37.68
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000400094.1
# P1_HM
# Full sequence identity: 28.29
# Whole PDB structure: 49.32
# Only interfaces: 56.67
# Only non-interfaces: 37.5
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000358337.3
# P1_HM
# Full sequence identity: 19.12
# Whole PDB structure: 34.72
# Only interfaces: 34.09
# Only non-interfaces: 35.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000298701.7 ENSP00000311032.4
# P2_HM
# Full sequence identity: 44.74
# Whole PDB structure: 48.63
# Only interfaces: 55.56
# Only non-interfaces: 37.5
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000358324.3
# P1_HM
# Full sequence identity: 44.74
# Whole PDB structure: 48.63
# Only interfaces: 55.56
# Only non-interfaces: 37.5
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000358321.1
# P1_HM
# Full sequence identity: 44.74
# Whole PDB structure: 48.63
# Only interfaces: 55.56
# Only non-interfaces: 37.5
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000398107.2
# P1_HM
# Full sequence identity: 49.82
# Whole PDB structure: 50.0
# Only interfaces: 57.3
# Only non-interfaces: 38.18
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000478999.1
# P1_HM
# Full sequence identity: 37.22
# Whole PDB structure: 48.59
# Only interfaces: 55.56
# Only non-interfaces: 36.54
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000478285.1
# P1_HM
# Full sequence identity: 19.12
# Whole PDB structure: 34.72
# Only interfaces: 34.09
# Only non-interfaces: 35.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000358327.3
# P1_HM
# Full sequence identity: 34.96
# Whole PDB structure: 49.66
# Only interfaces: 55.56
# Only non-interfaces: 40.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3ibf.pdb
# ENSP00000311032.4 ENSP00000358327.3
# P2_HM
# Full sequence identity: 37.11
# Whole PDB structure: 52.17
# Only interfaces: 59.77
# Only non-interfaces: 39.22
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_2xyg.pdb
# ENSP00000311032.4 ENSP00000480584.1
# P1_HM
# Full sequence identity: 44.74
# Whole PDB structure: 48.63
# Only interfaces: 55.56
# Only non-interfaces: 37.5
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000292408.4 ENSP00000410294.2
# P2_HM
# Full sequence identity: 54.63
# Whole PDB structure: 67.68
# Only interfaces: 55.56
# Only non-interfaces: 72.22
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000410294.2 ENSP00000424905.1
# P1_HM
# Full sequence identity: 7.59
# Whole PDB structure: 67.24
# Only interfaces: 43.75
# Only non-interfaces: 76.19
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000377259.2 ENSP00000410294.2
# P2_HM
# Full sequence identity: 49.28
# Whole PDB structure: 67.68
# Only interfaces: 55.56
# Only non-interfaces: 72.22
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000410294.2 ENSP00000426492.1
# P1_HM
# Full sequence identity: 4.14
# Whole PDB structure: 21.74
# Only interfaces: 33.33
# Only non-interfaces: 20.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000410294.2 ENSP00000424960.1
# P1_HM
# Full sequence identity: 54.63
# Whole PDB structure: 67.68
# Only interfaces: 55.56
# Only non-interfaces: 72.22
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000410294.2 ENSP00000427222.1
# P1_HM
# Full sequence identity: 2.43
# Whole PDB structure: 18.18
# Only interfaces: 0
# Only non-interfaces: 18.18
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000410294.2 ENSP00000422889.1
# P1_HM
# Full sequence identity: 2.42
# Whole PDB structure: 25.58
# Only interfaces: 44.44
# Only non-interfaces: 20.59
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000377254.1 ENSP00000410294.2
# P2_HM
# Full sequence identity: 52.4
# Whole PDB structure: 67.68
# Only interfaces: 55.56
# Only non-interfaces: 72.22
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000395164.1 ENSP00000410294.2
# P2_HM
# Full sequence identity: 3.16
# Whole PDB structure: 45.45
# Only interfaces: 0
# Only non-interfaces: 45.45
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000410294.2 ENSP00000424670.1
# P1_HM
# Full sequence identity: 20.7
# Whole PDB structure: 18.18
# Only interfaces: 33.33
# Only non-interfaces: 15.79
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_3caf.pdb
# ENSP00000410294.2 ENSP00000414914.2
# P1_HM
# Full sequence identity: 61.01
# Whole PDB structure: 72.16
# Only interfaces: 68.0
# ...
# ENSP00000365682.3 ENSP00000453435.1
# P1_HM
# Full sequence identity: 80.1
# Whole PDB structure: 89.29
# Only interfaces: 88.0
# Only non-interfaces: 100.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000394717.2
# P1_HM
# Full sequence identity: 79.59
# Whole PDB structure: 89.29
# Only interfaces: 88.0
# Only non-interfaces: 100.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000452809.1
# P1_HM
# Full sequence identity: 12.66
# Whole PDB structure: 66.67
# Only interfaces: 62.5
# Only non-interfaces: 100.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000457641.1
# P1_HM
# Full sequence identity: 10.88
# Whole PDB structure: 94.67
# Only interfaces: 93.65
# Only non-interfaces: 100.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000456178.1
# P1_HM
# Full sequence identity: 3.51
# Whole PDB structure: 95.24
# Only interfaces: 95.24
# Only non-interfaces: 0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000485965.1
# P1_HM
# Full sequence identity: 79.33
# Whole PDB structure: 89.29
# Only interfaces: 88.0
# Only non-interfaces: 100.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000262953.5 ENSP00000365682.3
# P2_HM
# Full sequence identity: 67.05
# Whole PDB structure: 86.24
# Only interfaces: 85.86
# Only non-interfaces: 90.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000468279.1
# P1_HM
# Full sequence identity: 58.41
# Whole PDB structure: 86.36
# Only interfaces: 86.0
# Only non-interfaces: 90.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000465519.1
# P1_HM
# Full sequence identity: 10.91
# Whole PDB structure: 84.72
# Only interfaces: 83.87
# Only non-interfaces: 90.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000392427.2
# P1_HM
# Full sequence identity: 56.33
# Whole PDB structure: 83.82
# Only interfaces: 83.61
# Only non-interfaces: 85.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000466542.1
# P1_HM
# Full sequence identity: 67.18
# Whole PDB structure: 86.36
# Only interfaces: 86.0
# Only non-interfaces: 90.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000465292.1
# P1_HM
# Full sequence identity: 29.35
# Whole PDB structure: 78.57
# Only interfaces: 79.17
# Only non-interfaces: 75.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000467337.1
# P1_HM
# Full sequence identity: 11.41
# Whole PDB structure: 93.1
# Only interfaces: 93.1
# Only non-interfaces: 0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000467358.1
# P1_HM
# Full sequence identity: 13.12
# Whole PDB structure: 87.5
# Only interfaces: 87.84
# Only non-interfaces: 83.33
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000468666.1
# P1_HM
# Full sequence identity: 17.49
# Whole PDB structure: 85.45
# Only interfaces: 85.86
# Only non-interfaces: 81.82
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000413107.2
# P1_HM
# Full sequence identity: 56.33
# Whole PDB structure: 83.82
# Only interfaces: 83.61
# Only non-interfaces: 85.71
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4om2.pdb
# ENSP00000365682.3 ENSP00000392869.2
# P1_HM
# Full sequence identity: 58.41
# Whole PDB structure: 86.36
# Only interfaces: 86.0
# Only non-interfaces: 90.0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4xz2.pdb
# ENSP00000269848.6 ENSP00000370517.4
# P2_HM
# Full sequence identity: 65.74
# Whole PDB structure: 69.22
# Only interfaces: 78.29
# Only non-interfaces: 67.19
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4xz2.pdb
# ENSP00000370517.4 ENSP00000381052.2
# P1_HM
# Full sequence identity: 3.57
# Whole PDB structure: 88.89
# Only interfaces: 75.0
# Only non-interfaces: 91.3
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4xz2.pdb
# ENSP00000370517.4 ENSP00000486076.1
# P1_HM
# Full sequence identity: 3.57
# Whole PDB structure: 88.89
# Only interfaces: 75.0
# Only non-interfaces: 91.3
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4tpt.pdb
# ENSP00000336740.2 ENSP00000339916.4
# P2_HM
# Full sequence identity: 45.94
# Whole PDB structure: 70.23
# Only interfaces: 80.9
# Only non-interfaces: 64.74
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4tpt.pdb
# ENSP00000339916.4 ENSP00000414606.1
# P1_HM
# Full sequence identity: 17.63
# Whole PDB structure: 36.36
# Only interfaces: 33.33
# Only non-interfaces: 42.86
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4tpt.pdb
# ENSP00000339916.4 ENSP00000444452.1
# P1_HM
# Full sequence identity: 47.12
# Whole PDB structure: 70.23
# Only interfaces: 80.9
# Only non-interfaces: 64.74
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5l2m.pdb
# ENSP00000297785.3 ENSP00000452789.1
# P1_HM
# Full sequence identity: 18.56
# Whole PDB structure: 64.58
# Only interfaces: 72.88
# Only non-interfaces: 58.82
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5l2m.pdb
# ENSP00000297785.3 ENSP00000332256.5
# P1_HM
# Full sequence identity: 68.36
# Whole PDB structure: 70.59
# Only interfaces: 72.07
# Only non-interfaces: 69.75
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5fhz.pdb
# ENSP00000297785.3 ENSP00000332256.5
# P2_HM
# Full sequence identity: 68.36
# Whole PDB structure: 70.96
# Only interfaces: 72.0
# Only non-interfaces: 70.5
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5l2m.pdb
# ENSP00000297785.3 ENSP00000454107.1
# P1_HM
# Full sequence identity: 14.65
# Whole PDB structure: 60.16
# Only interfaces: 64.29
# Only non-interfaces: 58.95
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5l2m.pdb
# ENSP00000297785.3 ENSP00000453328.1
# P1_HM
# Full sequence identity: 5.99
# Whole PDB structure: 29.7
# Only interfaces: 27.27
# Only non-interfaces: 31.58
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5l2m.pdb
# ENSP00000297785.3 ENSP00000343294.6
# P1_HM
# Full sequence identity: 54.1
# Whole PDB structure: 71.24
# Only interfaces: 70.5
# Only non-interfaces: 71.66
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000441364.1
# P1_HM
# Full sequence identity: 34.27
# Whole PDB structure: 71.76
# Only interfaces: 73.89
# Only non-interfaces: 66.1
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000362963.3
# P1_HM
# Full sequence identity: 40.03
# Whole PDB structure: 71.15
# Only interfaces: 72.89
# Only non-interfaces: 67.82
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000362947.1
# P1_HM
# Full sequence identity: 40.03
# Whole PDB structure: 71.15
# Only interfaces: 72.89
# Only non-interfaces: 67.82
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000410299.1
# P1_HM
# Full sequence identity: 9.05
# Whole PDB structure: 66.67
# Only interfaces: 67.86
# Only non-interfaces: 65.91
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000413350.1
# P1_HM
# Full sequence identity: 21.78
# Whole PDB structure: 67.7
# Only interfaces: 67.03
# Only non-interfaces: 68.57
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000415777.1
# P1_HM
# Full sequence identity: 2.97
# Whole PDB structure: 38.46
# Only interfaces: 42.86
# Only non-interfaces: 33.33
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000406673.1
# P1_HM
# Full sequence identity: 18.1
# Whole PDB structure: 72.26
# Only interfaces: 76.39
# Only non-interfaces: 68.67
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000409773.1
# P1_HM
# Full sequence identity: 24.19
# Whole PDB structure: 70.66
# Only interfaces: 72.41
# Only non-interfaces: 66.67
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000436038.1
# P1_HM
# Full sequence identity: 36.92
# Whole PDB structure: 73.91
# Only interfaces: 74.7
# Only non-interfaces: 72.41
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000435921.1
# P1_HM
# Full sequence identity: 36.92
# Whole PDB structure: 73.91
# Only interfaces: 74.7
# Only non-interfaces: 72.41
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000488975.1
# P1_HM
# Full sequence identity: 2.26
# Whole PDB structure: 0
# Only interfaces: 0
# Only non-interfaces: 0
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000393069.1
# P1_HM
# Full sequence identity: 22.91
# Whole PDB structure: 75.53
# Only interfaces: 78.22
# Only non-interfaces: 72.41
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_4wii.pdb
# ENSP00000349748.5 ENSP00000481916.1
# P1_HM
# Full sequence identity: 40.97
# Whole PDB structure: 73.91
# Only interfaces: 74.7
# Only non-interfaces: 72.41
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5fhz.pdb
# ENSP00000332256.5 ENSP00000366138.1
# P1_HM
# Full sequence identity: 29.69
# Whole PDB structure: 67.71
# Only interfaces: 69.09
# Only non-interfaces: 67.26
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5fhz.pdb
# ENSP00000332256.5 ENSP00000388026.1
# P1_HM
# Full sequence identity: 31.45
# Whole PDB structure: 69.26
# Only interfaces: 72.55
# Only non-interfaces: 68.33
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5fhz.pdb
# ENSP00000332256.5 ENSP00000401361.1
# P1_HM
# Full sequence identity: 25.78
# Whole PDB structure: 66.84
# Only interfaces: 72.55
# Only non-interfaces: 64.83
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5iko.pdb
# ENSP00000216962.3 ENSP00000366650.3
# P1_HM
# Full sequence identity: 73.55
# Whole PDB structure: 82.48
# Only interfaces: 84.68
# Only non-interfaces: 82.02
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5iko.pdb
# ENSP00000216962.3 ENSP00000431657.1
# P1_HM
# Full sequence identity: 78.42
# Whole PDB structure: 82.59
# Only interfaces: 86.89
# Only non-interfaces: 81.79
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5iko.pdb
# ENSP00000216962.3 ENSP00000443787.1
# P1_HM
# Full sequence identity: 77.33
# Whole PDB structure: 82.15
# Only interfaces: 86.29
# Only non-interfaces: 81.36
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000381526.3 ENSP00000427985.2
# P2_HM
# Full sequence identity: 62.83
# Whole PDB structure: 78.2
# Only interfaces: 78.33
# Only non-interfaces: 78.15
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000343690.5 ENSP00000427985.2
# P2_HM
# Full sequence identity: 65.46
# Whole PDB structure: 77.07
# Only interfaces: 78.33
# Only non-interfaces: 76.65
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000427985.2 ENSP00000430267.1
# P1_HM
# Full sequence identity: 23.19
# Whole PDB structure: 82.17
# Only interfaces: 86.11
# Only non-interfaces: 80.65
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000427985.2 ENSP00000428958.1
# P1_HM
# Full sequence identity: 8.42
# Whole PDB structure: 76.0
# Only interfaces: 54.17
# Only non-interfaces: 86.27
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000426720.1 ENSP00000427985.2
# P2_HM
# Full sequence identity: 10.49
# Whole PDB structure: 87.34
# Only interfaces: 100.0
# Only non-interfaces: 85.92
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000339850.3 ENSP00000427985.2
# P2_HM
# Full sequence identity: 62.24
# Whole PDB structure: 77.15
# Only interfaces: 73.33
# Only non-interfaces: 78.43
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000357616.1 ENSP00000427985.2
# P2_HM
# Full sequence identity: 45.05
# Whole PDB structure: 76.36
# Only interfaces: 66.28
# Only non-interfaces: 79.92
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000380987.2 ENSP00000427985.2
# P2_HM
# Full sequence identity: 62.83
# Whole PDB structure: 75.89
# Only interfaces: 71.67
# Only non-interfaces: 77.31
# ---------
# /media/axelle/Angel_backup/Dropbox/Hiver2019/Paralog_interference/Human_paralogs/006_dist_interfaces/dist_regions_5x1c.pdb
# ENSP00000425742.1 ENSP00000427985.2
# P2_HM
# Full sequence identity: 62.68
# Whole PDB structure: 75.89
# Only interfaces: 71.67
# Only non-interfaces: 77.31
# ---------

# %% [markdown]
# ## Use the isoform dictionary to select the best-matching isoforms
#
# I will also make sure to label paralog pairs by both the gene ID and the protein ID. This will help me match to Rohan's BioGRID data while also keeping the information about the isoforms.

# %%
handle = open(os.path.join(output_path, "Paralogs_sequence_identities_dist_2019-06-19.txt"), 'r')
reader = csv.reader(handle, delimiter = '\t')

similarity_dict = OrderedDict()

for entry in reader:
    P1 = entry[0]
    P2 = entry[1]
    
    # Skip header
    if P1 == 'P1_ID':
        continue

    full_seq_ident = float(entry[8])
        
    # Load all of these as a dictionary
    similarity_dict[(P1, P2)] = full_seq_ident
    similarity_dict[(P2, P1)] = full_seq_ident
        
handle.close()

# %%
# Define a function that gets the length of the matching chain in the PDB structure
def get_PDB_length(path_to_pdb_file, chain_query):
    '''
    A function designed to count the number of residues in a particular chain in a PDB structure.
    '''
    structure = parser.get_structure(path_to_pdb_file, path_to_pdb_file)
    
    res_no = 0
    
    for model in structure:
        for chain in model:
            if chain.get_id() == chain_query:
                for residue in chain.get_residues():
                    if residue.id[0] == ' ':
                        res_no +=1
                
    return(res_no)

# %%
parser = PDBParser()

handle = open(os.path.join(output_path, "Paralogs_sequence_identities_dist_2019-06-19.txt"), 'r')
reader = csv.reader(handle, delimiter = '\t')

out_handle = open(os.path.join("Data/Paralogs_sequence_identities_dist_best_isoforms_2019-06-19.txt"), 'w')
writer = csv.writer(out_handle, delimiter = '\t')

for entry in reader:
    P1 = entry[0]
    P2 = entry[1]
    
    # Skip header
    if P1 == 'P1_ID':
        header = entry
        header.append('Gene_1')
        header.append('Gene_2')
        header.append('PDB_length')
        header.append('Full_protein_length')
        writer.writerow(header)
        continue
       
    compared_struc = entry[7]
    
    gene_1 = isoform_to_gene_dict[P1]
    gene_2 = isoform_to_gene_dict[P2]
    
    # Initialize the best similarity as the one for this line
    best_similarity = similarity_dict[(P1, P2)]
    save_line = True
    
    # Select the best isoforms
    if compared_struc == 'P1_HM' or compared_struc == 'HET_P1':

        gene_2_isoforms = isoform_dict[gene_2]
        
        best_isoform = P2

        for isoform in gene_2_isoforms:
            # Check the sequence similarity with this isoform
            new_similarity = similarity_dict.get((P1, isoform), -1)
            if new_similarity > best_similarity:
                best_similarity = new_similarity
                best_isoform = isoform
                save_line = False
            elif new_similarity == best_similarity:
                # Helps identify identical isoforms
                print "Identical similarity for:", P2, "with", best_isoform, "and", isoform
    
        # Add the length of the protein chain from the PDB structure
        if compared_struc == 'P1_HM':
            pdb_structure = entry[5]
        elif 'HET_P1':
            pdb_structure = entry[4]
            
        matching_chain = alignment_dict[(P1, P2)][P1][pdb_structure[0:4]][0]
        
        protein_path = output_path_004_bio_assemblies + pdb_structure + '.pdb'
        
        pdb_length = get_PDB_length(protein_path, matching_chain)
        
        # Add the length of the full protein from the reference proteome
        full_protein_length = len(proteome_dict[P1].seq)
    
    elif compared_struc == 'P2_HM' or compared_struc == 'HET_P2':
        gene_1_isoforms = isoform_dict[gene_1]
        
        best_isoform = P1
        
        for isoform in gene_1_isoforms:
            # Check the sequence similarity with this isoform
            new_similarity = similarity_dict.get((isoform, P2), -1)
            if new_similarity > best_similarity:
                best_similarity = new_similarity
                best_isoform = isoform
                save_line = False
            elif new_similarity == best_similarity:
                print "Identical similarity for:", P1, "with", best_isoform, "and", isoform
                
                
        # Add the length of the protein chain from the PDB structure
        if compared_struc == 'P2_HM':
            pdb_structure = entry[6]
        elif 'HET_P2':
            pdb_structure = entry[4]
            
        matching_chain = alignment_dict[(P1, P2)][P2][pdb_structure[0:4]][0]
        
        protein_path = output_path_004_bio_assemblies + pdb_structure + '.pdb'
        
        pdb_length = get_PDB_length(protein_path, matching_chain)
        
        # Add the length of the full protein from the reference proteome
        full_protein_length = len(proteome_dict[P2].seq)
    
    if save_line:
        # This means that the current isoform pair is the best one for that pair of paralogs
        new_line = entry
        new_line.append(gene_1)
        new_line.append(gene_2)
        new_line.append(pdb_length)
        new_line.append(full_protein_length)
        writer.writerow(new_line)
                
            
handle.close()
out_handle.close()
# Out:
# Identical similarity for: ENSP00000264972.5 with ENSP00000264972.5 and ENSP00000264972.5
# Identical similarity for: ENSP00000497767.1 with ENSP00000497767.1 and ENSP00000497767.1
# Identical similarity for: ENSP00000497767.1 with ENSP00000497767.1 and ENSP00000363988.4
# Identical similarity for: ENSP00000497767.1 with ENSP00000497767.1 and ENSP00000497990.1
# Identical similarity for: ENSP00000497767.1 with ENSP00000497767.1 and ENSP00000497731.1
# Identical similarity for: ENSP00000363988.4 with ENSP00000363988.4 and ENSP00000497767.1
# Identical similarity for: ENSP00000363988.4 with ENSP00000363988.4 and ENSP00000363988.4
# Identical similarity for: ENSP00000363988.4 with ENSP00000363988.4 and ENSP00000497990.1
# Identical similarity for: ENSP00000363988.4 with ENSP00000363988.4 and ENSP00000497731.1
# Identical similarity for: ENSP00000497990.1 with ENSP00000497990.1 and ENSP00000497767.1
# Identical similarity for: ENSP00000497990.1 with ENSP00000497990.1 and ENSP00000363988.4
# Identical similarity for: ENSP00000497990.1 with ENSP00000497990.1 and ENSP00000497990.1
# Identical similarity for: ENSP00000497990.1 with ENSP00000497990.1 and ENSP00000497731.1
# Identical similarity for: ENSP00000497731.1 with ENSP00000497731.1 and ENSP00000497767.1
# Identical similarity for: ENSP00000497731.1 with ENSP00000497731.1 and ENSP00000363988.4
# Identical similarity for: ENSP00000497731.1 with ENSP00000497731.1 and ENSP00000497990.1
# Identical similarity for: ENSP00000497731.1 with ENSP00000497731.1 and ENSP00000497731.1
# Identical similarity for: ENSP00000497216.1 with ENSP00000497767.1 and ENSP00000363988.4
# Identical similarity for: ENSP00000497216.1 with ENSP00000497767.1 and ENSP00000497990.1
# Identical similarity for: ENSP00000497216.1 with ENSP00000497767.1 and ENSP00000497731.1
# Identical similarity for: ENSP00000497985.1 with ENSP00000497767.1 and ENSP00000363988.4
# Identical similarity for: ENSP00000497985.1 with ENSP00000497767.1 and ENSP00000497990.1
# Identical similarity for: ENSP00000497985.1 with ENSP00000497767.1 and ENSP00000497731.1
# Identical similarity for: ENSP00000481363.1 with ENSP00000497767.1 and ENSP00000363988.4
# Identical similarity for: ENSP00000481363.1 with ENSP00000497767.1 and ENSP00000497990.1
# Identical similarity for: ENSP00000481363.1 with ENSP00000497767.1 and ENSP00000497731.1
# Identical similarity for: ENSP00000378729.3 with ENSP00000378729.3 and ENSP00000378729.3
# Identical similarity for: ENSP00000378729.3 with ENSP00000378731.2 and ENSP00000226253.4
# Identical similarity for: ENSP00000457468.2 with ENSP00000455700.1 and ENSP00000455800.2
# Identical similarity for: ENSP00000457468.2 with ENSP00000455700.1 and ENSP00000400452.2
# Identical similarity for: ENSP00000457468.2 with ENSP00000455700.1 and ENSP00000455917.1
# Identical similarity for: ENSP00000457468.2 with ENSP00000455700.1 and ENSP00000494188.1
# Identical similarity for: ENSP00000378731.2 with ENSP00000378731.2 and ENSP00000378731.2
# Identical similarity for: ENSP00000378731.2 with ENSP00000378731.2 and ENSP00000226253.4
# Identical similarity for: ENSP00000226253.4 with ENSP00000226253.4 and ENSP00000378731.2
# Identical similarity for: ENSP00000226253.4 with ENSP00000226253.4 and ENSP00000226253.4
# Identical similarity for: ENSP00000463174.2 with ENSP00000378731.2 and ENSP00000226253.4
# Identical similarity for: ENSP00000462674.1 with ENSP00000378731.2 and ENSP00000226253.4
# Identical similarity for: ENSP00000465623.1 with ENSP00000378731.2 and ENSP00000226253.4
# Identical similarity for: ENSP00000398976.1 with ENSP00000378731.2 and ENSP00000226253.4
# Identical similarity for: ENSP00000463118.1 with ENSP00000378731.2 and ENSP00000226253.4
# Identical similarity for: ENSP00000420756.1 with ENSP00000420756.1 and ENSP00000420756.1
# Identical similarity for: ENSP00000420756.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000418742.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000399400.2 with ENSP00000399400.2 and ENSP00000399400.2
# Identical similarity for: ENSP00000399400.2 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000345096.6 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000420803.1 with ENSP00000420803.1 and ENSP00000420803.1
# Identical similarity for: ENSP00000420803.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000346219.5 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000265385.8 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000417296.1 with ENSP00000417296.1 and ENSP00000417296.1
# Identical similarity for: ENSP00000417296.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000496892.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000420185.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000419609.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000418592.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000420469.1 with ENSP00000417296.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000486056.1 with ENSP00000486056.1 and ENSP00000417296.1
# Identical similarity for: ENSP00000486056.1 with ENSP00000486056.1 and ENSP00000486056.1
# Identical similarity for: ENSP00000270279.3 with ENSP00000270279.3 and ENSP00000270279.3
# Identical similarity for: ENSP00000270279.3 with ENSP00000270279.3 and ENSP00000494162.1
# Identical similarity for: ENSP00000340250.4 with ENSP00000270279.3 and ENSP00000494162.1
# Identical similarity for: ENSP00000494162.1 with ENSP00000494162.1 and ENSP00000270279.3
# Identical similarity for: ENSP00000494162.1 with ENSP00000494162.1 and ENSP00000494162.1
# Identical similarity for: ENSP00000495258.1 with ENSP00000270279.3 and ENSP00000494162.1
# Identical similarity for: ENSP00000377598.4 with ENSP00000377598.4 and ENSP00000377598.4
# Identical similarity for: ENSP00000377598.4 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000496297.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000264122.4 with ENSP00000264122.4 and ENSP00000377598.4
# Identical similarity for: ENSP00000264122.4 with ENSP00000264122.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000494383.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000496708.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000494262.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000496761.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000496352.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000384816.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000384938.1 with ENSP00000384938.1 and ENSP00000384938.1
# Identical similarity for: ENSP00000400949.2 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000494989.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000409750.2 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000393906.2 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000495754.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000499037.1 with ENSP00000377598.4 and ENSP00000264122.4
# Identical similarity for: ENSP00000370912.3 with ENSP00000370912.3 and ENSP00000370912.3
# Identical similarity for: ENSP00000264316.4 with ENSP00000264316.4 and ENSP00000264316.4
# Identical similarity for: ENSP00000295025.7 with ENSP00000295025.7 and ENSP00000295025.7
# Identical similarity for: ENSP00000377989.3 with ENSP00000377989.3 and ENSP00000377989.3
# Identical similarity for: ENSP00000221452.7 with ENSP00000221452.7 and ENSP00000221452.7
# Identical similarity for: ENSP00000221452.7 with ENSP00000221452.7 and ENSP00000485826.1
# Identical similarity for: ENSP00000427348.1 with ENSP00000221452.7 and ENSP00000485826.1
# Identical similarity for: ENSP00000423287.1 with ENSP00000221452.7 and ENSP00000485826.1
# Identical similarity for: ENSP00000468460.1 with ENSP00000221452.7 and ENSP00000485826.1
# Identical similarity for: ENSP00000485826.1 with ENSP00000485826.1 and ENSP00000221452.7
# Identical similarity for: ENSP00000485826.1 with ENSP00000485826.1 and ENSP00000485826.1
# Identical similarity for: ENSP00000428924.1 with ENSP00000428924.1 and ENSP00000428924.1
# Identical similarity for: ENSP00000428424.1 with ENSP00000428424.1 and ENSP00000428424.1
# Identical similarity for: ENSP00000365022.2 with ENSP00000365022.2 and ENSP00000365022.2
# Identical similarity for: ENSP00000365022.2 with ENSP00000486627.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000486627.1 with ENSP00000486627.1 and ENSP00000486627.1
# Identical similarity for: ENSP00000486627.1 with ENSP00000486627.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000420457.1 with ENSP00000486627.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000262651.3 with ENSP00000486627.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000429848.1 with ENSP00000429848.1 and ENSP00000486627.1
# Identical similarity for: ENSP00000429848.1 with ENSP00000429848.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000427757.1 with ENSP00000427757.1 and ENSP00000427757.1
# Identical similarity for: ENSP00000365012.2 with ENSP00000486627.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000441169.1 with ENSP00000441169.1 and ENSP00000486627.1
# Identical similarity for: ENSP00000441169.1 with ENSP00000441169.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000444986.3 with ENSP00000486627.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000491964.1 with ENSP00000486627.1 and ENSP00000429848.1
# Identical similarity for: ENSP00000219406.6 with ENSP00000219406.6 and ENSP00000219406.6
# Identical similarity for: ENSP00000384410.1 with ENSP00000384410.1 and ENSP00000384410.1
# Identical similarity for: ENSP00000305465.4 with ENSP00000305465.4 and ENSP00000305465.4
# Identical similarity for: ENSP00000261336.2 with ENSP00000261336.2 and ENSP00000261336.2
# Identical similarity for: ENSP00000352929.3 with ENSP00000352929.3 and ENSP00000352929.3
# Identical similarity for: ENSP00000352929.3 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000352929.3 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000400494.1 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000400494.1 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000403610.1 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000403610.1 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000384074.1 with ENSP00000384074.1 and ENSP00000352929.3
# Identical similarity for: ENSP00000384074.1 with ENSP00000384074.1 and ENSP00000384074.1
# Identical similarity for: ENSP00000384074.1 with ENSP00000384074.1 and ENSP00000380044.1
# Identical similarity for: ENSP00000412194.1 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000412194.1 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000407235.2 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000407235.2 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000384426.3 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000384426.3 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000397460.1 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000397460.1 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000403057.1 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000403057.1 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000412335.1 with ENSP00000352929.3 and ENSP00000384074.1
# Identical similarity for: ENSP00000412335.1 with ENSP00000352929.3 and ENSP00000380044.1
# Identical similarity for: ENSP00000380044.1 with ENSP00000380044.1 and ENSP00000352929.3
# Identical similarity for: ENSP00000380044.1 with ENSP00000380044.1 and ENSP00000384074.1
# Identical similarity for: ENSP00000380044.1 with ENSP00000380044.1 and ENSP00000380044.1
# Identical similarity for: ENSP00000367545.4 with ENSP00000367545.4 and ENSP00000367545.4
# Identical similarity for: ENSP00000334382.6 with ENSP00000334382.6 and ENSP00000334382.6
# Identical similarity for: ENSP00000302625.5 with ENSP00000302625.5 and ENSP00000302625.5
# Identical similarity for: ENSP00000356707.2 with ENSP00000356707.2 and ENSP00000356707.2
# Identical similarity for: ENSP00000347457.5 with ENSP00000347457.5 and ENSP00000347457.5
# Identical similarity for: ENSP00000486701.1 with ENSP00000486701.1 and ENSP00000486701.1
# Identical similarity for: ENSP00000356705.1 with ENSP00000356705.1 and ENSP00000356705.1
# Identical similarity for: ENSP00000468734.1 with ENSP00000468734.1 and ENSP00000468734.1
# Identical similarity for: ENSP00000347890.6 with ENSP00000347890.6 and ENSP00000347890.6
# Identical similarity for: ENSP00000338934.7 with ENSP00000338934.7 and ENSP00000338934.7
# Identical similarity for: ENSP00000338934.7 with ENSP00000338934.7 and ENSP00000356042.3
# Identical similarity for: ENSP00000356042.3 with ENSP00000356042.3 and ENSP00000338934.7
# Identical similarity for: ENSP00000356042.3 with ENSP00000356042.3 and ENSP00000356042.3
# Identical similarity for: ENSP00000376016.5 with ENSP00000376016.5 and ENSP00000376016.5
# Identical similarity for: ENSP00000345023.1 with ENSP00000345023.1 and ENSP00000345023.1
# Identical similarity for: ENSP00000395605.1 with ENSP00000395605.1 and ENSP00000395605.1
# Identical similarity for: ENSP00000219302.3 with ENSP00000219302.3 and ENSP00000219302.3
# Identical similarity for: ENSP00000216962.3 with ENSP00000216962.3 and ENSP00000216962.3
# Identical similarity for: ENSP00000216392.7 with ENSP00000216392.7 and ENSP00000216392.7
# Identical similarity for: ENSP00000215095.5 with ENSP00000215095.5 and ENSP00000215095.5
# Identical similarity for: ENSP00000261464.5 with ENSP00000261464.5 and ENSP00000261464.5
# Identical similarity for: ENSP00000261464.5 with ENSP00000261464.5 and ENSP00000355971.3
# Identical similarity for: ENSP00000261464.5 with ENSP00000261464.5 and ENSP00000336825.2
# Identical similarity for: ENSP00000355971.3 with ENSP00000355971.3 and ENSP00000261464.5
# Identical similarity for: ENSP00000355971.3 with ENSP00000355971.3 and ENSP00000355971.3
# Identical similarity for: ENSP00000355971.3 with ENSP00000355971.3 and ENSP00000336825.2
# Identical similarity for: ENSP00000336825.2 with ENSP00000336825.2 and ENSP00000261464.5
# Identical similarity for: ENSP00000336825.2 with ENSP00000336825.2 and ENSP00000355971.3
# Identical similarity for: ENSP00000336825.2 with ENSP00000336825.2 and ENSP00000336825.2
# Identical similarity for: ENSP00000495159.1 with ENSP00000495159.1 and ENSP00000495159.1
# Identical similarity for: ENSP00000282397.4 with ENSP00000282397.4 and ENSP00000282397.4
# Identical similarity for: ENSP00000400094.1 with ENSP00000400094.1 and ENSP00000400094.1
# Identical similarity for: ENSP00000400094.1 with ENSP00000298701.7 and ENSP00000358324.3
# Identical similarity for: ENSP00000400094.1 with ENSP00000298701.7 and ENSP00000358321.1
# Identical similarity for: ENSP00000358337.3 with ENSP00000298701.7 and ENSP00000358324.3
# Identical similarity for: ENSP00000358337.3 with ENSP00000298701.7 and ENSP00000358321.1
# Identical similarity for: ENSP00000298701.7 with ENSP00000298701.7 and ENSP00000298701.7
# Identical similarity for: ENSP00000298701.7 with ENSP00000298701.7 and ENSP00000358324.3
# Identical similarity for: ENSP00000298701.7 with ENSP00000298701.7 and ENSP00000358321.1
# Identical similarity for: ENSP00000358324.3 with ENSP00000358324.3 and ENSP00000298701.7
# Identical similarity for: ENSP00000358324.3 with ENSP00000358324.3 and ENSP00000358324.3
# Identical similarity for: ENSP00000358324.3 with ENSP00000358324.3 and ENSP00000358321.1
# Identical similarity for: ENSP00000358321.1 with ENSP00000358321.1 and ENSP00000298701.7
# Identical similarity for: ENSP00000358321.1 with ENSP00000358321.1 and ENSP00000358324.3
# Identical similarity for: ENSP00000358321.1 with ENSP00000358321.1 and ENSP00000358321.1
# Identical similarity for: ENSP00000398107.2 with ENSP00000398107.2 and ENSP00000398107.2
# Identical similarity for: ENSP00000478999.1 with ENSP00000298701.7 and ENSP00000358324.3
# Identical similarity for: ENSP00000478999.1 with ENSP00000298701.7 and ENSP00000358321.1
# Identical similarity for: ENSP00000478285.1 with ENSP00000298701.7 and ENSP00000358324.3
# Identical similarity for: ENSP00000478285.1 with ENSP00000298701.7 and ENSP00000358321.1
# Identical similarity for: ENSP00000358327.3 with ENSP00000298701.7 and ENSP00000358324.3
# Identical similarity for: ENSP00000358327.3 with ENSP00000298701.7 and ENSP00000358321.1
# Identical similarity for: ENSP00000311032.4 with ENSP00000311032.4 and ENSP00000311032.4
# Identical similarity for: ENSP00000311032.4 with ENSP00000311032.4 and ENSP00000428929.1
# Identical similarity for: ENSP00000480584.1 with ENSP00000480584.1 and ENSP00000298701.7
# Identical similarity for: ENSP00000480584.1 with ENSP00000480584.1 and ENSP00000358324.3
# Identical similarity for: ENSP00000480584.1 with ENSP00000480584.1 and ENSP00000358321.1
# Identical similarity for: ENSP00000292408.4 with ENSP00000292408.4 and ENSP00000292408.4
# Identical similarity for: ENSP00000292408.4 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000424905.1 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000377259.2 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000426492.1 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000424960.1 with ENSP00000424960.1 and ENSP00000292408.4
# Identical similarity for: ENSP00000424960.1 with ENSP00000424960.1 and ENSP00000424960.1
# Identical similarity for: ENSP00000427222.1 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000422889.1 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000377254.1 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000395164.1 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000424670.1 with ENSP00000292408.4 and ENSP00000424960.1
# Identical similarity for: ENSP00000414914.2 with ENSP00000414914.2 and ENSP00000414914.2
# Identical similarity for: ENSP00000492432.1 with ENSP00000492432.1 and ENSP00000492432.1
# Identical similarity for: ENSP00000466598.2 with ENSP00000466598.2 and ENSP00000466598.2
# Identical similarity for: ENSP00000363071.3 with ENSP00000363071.3 and ENSP00000363071.3
# Identical similarity for: ENSP00000488924.1 with ENSP00000488924.1 and ENSP00000488924.1
# Identical similarity for: ENSP00000269142.5 with ENSP00000269142.5 and ENSP00000269142.5
# Identical similarity for: ENSP00000252699.2 with ENSP00000252699.2 and ENSP00000252699.2
# Identical similarity for: ENSP00000193403.6 with ENSP00000193403.6 and ENSP00000193403.6
# Identical similarity for: ENSP00000414272.2 with ENSP00000414272.2 and ENSP00000414272.2
# Identical similarity for: ENSP00000277853.5 with ENSP00000277853.5 and ENSP00000277853.5
# Identical similarity for: ENSP00000378032.3 with ENSP00000378032.3 and ENSP00000378032.3
# Identical similarity for: ENSP00000378032.3 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000424247.1 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000425824.1 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000381412.3 with ENSP00000381412.3 and ENSP00000381412.3
# Identical similarity for: ENSP00000339740.5 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000423482.1 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000423677.1 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000378030.3 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000424245.1 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000369098.2 with ENSP00000369098.2 and ENSP00000378032.3
# Identical similarity for: ENSP00000369098.2 with ENSP00000369098.2 and ENSP00000369098.2
# Identical similarity for: ENSP00000422566.1 with ENSP00000422566.1 and ENSP00000422566.1
# Identical similarity for: ENSP00000423753.1 with ENSP00000378032.3 and ENSP00000369098.2
# Identical similarity for: ENSP00000296402.5 with ENSP00000296402.5 and ENSP00000378032.3
# Identical similarity for: ENSP00000296402.5 with ENSP00000296402.5 and ENSP00000369098.2
# Identical similarity for: ENSP00000458435.1 with ENSP00000458435.1 and ENSP00000458435.1
# Identical similarity for: ENSP00000458435.1 with ENSP00000458435.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000458435.1 with ENSP00000458435.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000458435.1 with ENSP00000458435.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000458435.1 with ENSP00000458435.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000458435.1 with ENSP00000458435.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000458435.1 with ENSP00000458435.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000331514.2 with ENSP00000331514.2 and ENSP00000458435.1
# Identical similarity for: ENSP00000331514.2 with ENSP00000331514.2 and ENSP00000331514.2
# Identical similarity for: ENSP00000331514.2 with ENSP00000331514.2 and ENSP00000458162.1
# Identical similarity for: ENSP00000331514.2 with ENSP00000331514.2 and ENSP00000459124.1
# Identical similarity for: ENSP00000331514.2 with ENSP00000331514.2 and ENSP00000461672.1
# Identical similarity for: ENSP00000331514.2 with ENSP00000331514.2 and ENSP00000493648.1
# Identical similarity for: ENSP00000331514.2 with ENSP00000331514.2 and ENSP00000477968.1
# Identical similarity for: ENSP00000458162.1 with ENSP00000458162.1 and ENSP00000458435.1
# Identical similarity for: ENSP00000458162.1 with ENSP00000458162.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000458162.1 with ENSP00000458162.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000458162.1 with ENSP00000458162.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000458162.1 with ENSP00000458162.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000458162.1 with ENSP00000458162.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000458162.1 with ENSP00000458162.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000459124.1 with ENSP00000459124.1 and ENSP00000458435.1
# Identical similarity for: ENSP00000459124.1 with ENSP00000459124.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000459124.1 with ENSP00000459124.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000459124.1 with ENSP00000459124.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000459124.1 with ENSP00000459124.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000459124.1 with ENSP00000459124.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000459124.1 with ENSP00000459124.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000461672.1 with ENSP00000461672.1 and ENSP00000458435.1
# Identical similarity for: ENSP00000461672.1 with ENSP00000461672.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000461672.1 with ENSP00000461672.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000461672.1 with ENSP00000461672.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000461672.1 with ENSP00000461672.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000461672.1 with ENSP00000461672.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000461672.1 with ENSP00000461672.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000493648.1 with ENSP00000493648.1 and ENSP00000458435.1
# Identical similarity for: ENSP00000493648.1 with ENSP00000493648.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000493648.1 with ENSP00000493648.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000493648.1 with ENSP00000493648.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000493648.1 with ENSP00000493648.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000493648.1 with ENSP00000493648.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000493648.1 with ENSP00000493648.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000462823.1 with ENSP00000458435.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000462823.1 with ENSP00000458435.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000462823.1 with ENSP00000458435.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000462823.1 with ENSP00000458435.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000462823.1 with ENSP00000458435.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000462823.1 with ENSP00000458435.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000461407.1 with ENSP00000458435.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000461407.1 with ENSP00000458435.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000461407.1 with ENSP00000458435.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000461407.1 with ENSP00000458435.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000461407.1 with ENSP00000458435.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000461407.1 with ENSP00000458435.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000460464.1 with ENSP00000458435.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000460464.1 with ENSP00000458435.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000460464.1 with ENSP00000458435.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000460464.1 with ENSP00000458435.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000460464.1 with ENSP00000458435.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000460464.1 with ENSP00000458435.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000459119.1 with ENSP00000458435.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000459119.1 with ENSP00000458435.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000459119.1 with ENSP00000458435.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000459119.1 with ENSP00000458435.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000459119.1 with ENSP00000458435.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000459119.1 with ENSP00000458435.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000460660.1 with ENSP00000458435.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000460660.1 with ENSP00000458435.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000460660.1 with ENSP00000458435.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000460660.1 with ENSP00000458435.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000460660.1 with ENSP00000458435.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000460660.1 with ENSP00000458435.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000466346.1 with ENSP00000458435.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000466346.1 with ENSP00000458435.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000466346.1 with ENSP00000458435.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000466346.1 with ENSP00000458435.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000466346.1 with ENSP00000458435.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000466346.1 with ENSP00000458435.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000477968.1 with ENSP00000477968.1 and ENSP00000458435.1
# Identical similarity for: ENSP00000477968.1 with ENSP00000477968.1 and ENSP00000331514.2
# Identical similarity for: ENSP00000477968.1 with ENSP00000477968.1 and ENSP00000458162.1
# Identical similarity for: ENSP00000477968.1 with ENSP00000477968.1 and ENSP00000459124.1
# Identical similarity for: ENSP00000477968.1 with ENSP00000477968.1 and ENSP00000461672.1
# Identical similarity for: ENSP00000477968.1 with ENSP00000477968.1 and ENSP00000493648.1
# Identical similarity for: ENSP00000477968.1 with ENSP00000477968.1 and ENSP00000477968.1
# Identical similarity for: ENSP00000437783.1 with ENSP00000437783.1 and ENSP00000437783.1
# Identical similarity for: ENSP00000437783.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000379518.3 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000280704.3 with ENSP00000280704.3 and ENSP00000437783.1
# Identical similarity for: ENSP00000280704.3 with ENSP00000280704.3 and ENSP00000280704.3
# Identical similarity for: ENSP00000438196.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000441991.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000443414.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000439555.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000441478.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000439060.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000443997.1 with ENSP00000437783.1 and ENSP00000280704.3
# Identical similarity for: ENSP00000395337.3 with ENSP00000395337.3 and ENSP00000395337.3
# Identical similarity for: ENSP00000395337.3 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000395337.3 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000440161.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000440161.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000443545.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000443545.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000406172.2 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000406172.2 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000379524.2 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000379524.2 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000444292.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000444292.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000442979.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000442979.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000440368.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000440368.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000441058.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000441058.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000443362.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000443362.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000442637.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000442637.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000227157.4 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000227157.4 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000441241.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000441241.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000446415.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000446415.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000368722.5 with ENSP00000368722.5 and ENSP00000395337.3
# Identical similarity for: ENSP00000368722.5 with ENSP00000368722.5 and ENSP00000368722.5
# Identical similarity for: ENSP00000368722.5 with ENSP00000368722.5 and ENSP00000445331.1
# Identical similarity for: ENSP00000445331.1 with ENSP00000445331.1 and ENSP00000395337.3
# Identical similarity for: ENSP00000445331.1 with ENSP00000445331.1 and ENSP00000368722.5
# Identical similarity for: ENSP00000445331.1 with ENSP00000445331.1 and ENSP00000445331.1
# Identical similarity for: ENSP00000441699.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000441699.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000445175.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000445175.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000379386.1 with ENSP00000379386.1 and ENSP00000379386.1
# Identical similarity for: ENSP00000379386.1 with ENSP00000379386.1 and ENSP00000229319.1
# Identical similarity for: ENSP00000486249.1 with ENSP00000395337.3 and ENSP00000368722.5
# Identical similarity for: ENSP00000486249.1 with ENSP00000395337.3 and ENSP00000445331.1
# Identical similarity for: ENSP00000379500.2 with ENSP00000379500.2 and ENSP00000379500.2
# Identical similarity for: ENSP00000368697.4 with ENSP00000368697.4 and ENSP00000368697.4
# Identical similarity for: ENSP00000379500.2 with ENSP00000379500.2 and ENSP00000379500.2
# Identical similarity for: ENSP00000368697.4 with ENSP00000368697.4 and ENSP00000368697.4
# Identical similarity for: ENSP00000229319.1 with ENSP00000229319.1 and ENSP00000379386.1
# Identical similarity for: ENSP00000229319.1 with ENSP00000229319.1 and ENSP00000229319.1
# Identical similarity for: ENSP00000379385.1 with ENSP00000379386.1 and ENSP00000229319.1
# Identical similarity for: ENSP00000398015.1 with ENSP00000379386.1 and ENSP00000229319.1
# Identical similarity for: ENSP00000442680.1 with ENSP00000379386.1 and ENSP00000229319.1
# Identical similarity for: ENSP00000377210.2 with ENSP00000377210.2 and ENSP00000377210.2
# Identical similarity for: ENSP00000377210.2 with ENSP00000311032.4 and ENSP00000428929.1
# Identical similarity for: ENSP00000428929.1 with ENSP00000428929.1 and ENSP00000311032.4
# Identical similarity for: ENSP00000428929.1 with ENSP00000428929.1 and ENSP00000428929.1
# Identical similarity for: ENSP00000428372.1 with ENSP00000428372.1 and ENSP00000377210.2
# Identical similarity for: ENSP00000428372.1 with ENSP00000311032.4 and ENSP00000428929.1
# Identical similarity for: ENSP00000377213.4 with ENSP00000377213.4 and ENSP00000377210.2
# Identical similarity for: ENSP00000377213.4 with ENSP00000311032.4 and ENSP00000428929.1
# Identical similarity for: ENSP00000407142.2 with ENSP00000311032.4 and ENSP00000428929.1
# Identical similarity for: ENSP00000327054.3 with ENSP00000327054.3 and ENSP00000327054.3
# Identical similarity for: ENSP00000486528.1 with ENSP00000486528.1 and ENSP00000486528.1
# Identical similarity for: ENSP00000261366.5 with ENSP00000261366.5 and ENSP00000261366.5
# Identical similarity for: ENSP00000426768.1 with ENSP00000426768.1 and ENSP00000426768.1
# Identical similarity for: ENSP00000426768.1 with ENSP00000426768.1 and ENSP00000320430.4
# Identical similarity for: ENSP00000426768.1 with ENSP00000426768.1 and ENSP00000483535.1
# Identical similarity for: ENSP00000320430.4 with ENSP00000320430.4 and ENSP00000426768.1
# Identical similarity for: ENSP00000320430.4 with ENSP00000320430.4 and ENSP00000320430.4
# Identical similarity for: ENSP00000320430.4 with ENSP00000320430.4 and ENSP00000483535.1
# Identical similarity for: ENSP00000483535.1 with ENSP00000483535.1 and ENSP00000426768.1
# Identical similarity for: ENSP00000483535.1 with ENSP00000483535.1 and ENSP00000320430.4
# Identical similarity for: ENSP00000483535.1 with ENSP00000483535.1 and ENSP00000483535.1
# Identical similarity for: ENSP00000386935.3 with ENSP00000386935.3 and ENSP00000386935.3
# Identical similarity for: ENSP00000380638.1 with ENSP00000380638.1 and ENSP00000380638.1
# Identical similarity for: ENSP00000380638.1 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000429694.1 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000430404.1 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000332816.6 with ENSP00000332816.6 and ENSP00000380638.1
# Identical similarity for: ENSP00000332816.6 with ENSP00000332816.6 and ENSP00000332816.6
# Identical similarity for: ENSP00000428271.1 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000416174.1 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000427931.1 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000428837.1 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000391995.2 with ENSP00000380638.1 and ENSP00000332816.6
# Identical similarity for: ENSP00000441954.2 with ENSP00000441954.2 and ENSP00000441954.2
# Identical similarity for: ENSP00000441954.2 with ENSP00000441954.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000441954.2 with ENSP00000441954.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000425749.1 with ENSP00000441954.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000425749.1 with ENSP00000441954.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000424279.1 with ENSP00000441954.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000424279.1 with ENSP00000441954.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000426696.2 with ENSP00000426696.2 and ENSP00000441954.2
# Identical similarity for: ENSP00000426696.2 with ENSP00000426696.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000426696.2 with ENSP00000426696.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000427330.1 with ENSP00000441954.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000427330.1 with ENSP00000441954.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000422954.1 with ENSP00000441954.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000422954.1 with ENSP00000441954.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000427474.1 with ENSP00000441954.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000427474.1 with ENSP00000441954.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000427650.1 with ENSP00000441954.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000427650.1 with ENSP00000441954.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000446474.2 with ENSP00000446474.2 and ENSP00000441954.2
# Identical similarity for: ENSP00000446474.2 with ENSP00000446474.2 and ENSP00000426696.2
# Identical similarity for: ENSP00000446474.2 with ENSP00000446474.2 and ENSP00000446474.2
# Identical similarity for: ENSP00000382216.2 with ENSP00000382216.2 and ENSP00000382216.2
# Identical similarity for: ENSP00000382216.2 with ENSP00000382216.2 and ENSP00000369154.4
# Identical similarity for: ENSP00000239885.6 with ENSP00000382216.2 and ENSP00000369154.4
# Identical similarity for: ENSP00000369154.4 with ENSP00000369154.4 and ENSP00000382216.2
# Identical similarity for: ENSP00000369154.4 with ENSP00000369154.4 and ENSP00000369154.4
# Identical similarity for: ENSP00000396467.1 with ENSP00000396467.1 and ENSP00000396467.1
# Identical similarity for: ENSP00000396467.1 with ENSP00000396467.1 and ENSP00000350639.2
# Identical similarity for: ENSP00000396467.1 with ENSP00000396467.1 and ENSP00000478922.1
# Identical similarity for: ENSP00000410970.1 with ENSP00000396467.1 and ENSP00000350639.2
# Identical similarity for: ENSP00000410970.1 with ENSP00000396467.1 and ENSP00000478922.1
# Identical similarity for: ENSP00000350639.2 with ENSP00000350639.2 and ENSP00000396467.1
# Identical similarity for: ENSP00000350639.2 with ENSP00000350639.2 and ENSP00000350639.2
# Identical similarity for: ENSP00000350639.2 with ENSP00000350639.2 and ENSP00000478922.1
# Identical similarity for: ENSP00000402045.1 with ENSP00000396467.1 and ENSP00000350639.2
# Identical similarity for: ENSP00000402045.1 with ENSP00000396467.1 and ENSP00000478922.1
# Identical similarity for: ENSP00000394894.1 with ENSP00000396467.1 and ENSP00000350639.2
# Identical similarity for: ENSP00000394894.1 with ENSP00000396467.1 and ENSP00000478922.1
# Identical similarity for: ENSP00000478922.1 with ENSP00000478922.1 and ENSP00000396467.1
# Identical similarity for: ENSP00000478922.1 with ENSP00000478922.1 and ENSP00000350639.2
# Identical similarity for: ENSP00000478922.1 with ENSP00000478922.1 and ENSP00000478922.1
# Identical similarity for: ENSP00000379701.2 with ENSP00000379701.2 and ENSP00000379701.2
# Identical similarity for: ENSP00000338615.5 with ENSP00000338615.5 and ENSP00000338615.5
# Identical similarity for: ENSP00000338615.5 with ENSP00000338615.5 and ENSP00000434630.1
# Identical similarity for: ENSP00000338615.5 with ENSP00000338615.5 and ENSP00000436285.1
# Identical similarity for: ENSP00000338615.5 with ENSP00000338615.5 and ENSP00000410474.2
# Identical similarity for: ENSP00000311825.6 with ENSP00000338615.5 and ENSP00000434630.1
# Identical similarity for: ENSP00000311825.6 with ENSP00000338615.5 and ENSP00000436285.1
# Identical similarity for: ENSP00000311825.6 with ENSP00000338615.5 and ENSP00000410474.2
# Identical similarity for: ENSP00000357816.5 with ENSP00000338615.5 and ENSP00000434630.1
# Identical similarity for: ENSP00000357816.5 with ENSP00000338615.5 and ENSP00000436285.1
# Identical similarity for: ENSP00000357816.5 with ENSP00000338615.5 and ENSP00000410474.2
# Identical similarity for: ENSP00000434630.1 with ENSP00000434630.1 and ENSP00000338615.5
# Identical similarity for: ENSP00000434630.1 with ENSP00000434630.1 and ENSP00000434630.1
# Identical similarity for: ENSP00000434630.1 with ENSP00000434630.1 and ENSP00000436285.1
# Identical similarity for: ENSP00000434630.1 with ENSP00000434630.1 and ENSP00000410474.2
# Identical similarity for: ENSP00000436285.1 with ENSP00000436285.1 and ENSP00000338615.5
# Identical similarity for: ENSP00000436285.1 with ENSP00000436285.1 and ENSP00000434630.1
# Identical similarity for: ENSP00000436285.1 with ENSP00000436285.1 and ENSP00000436285.1
# Identical similarity for: ENSP00000436285.1 with ENSP00000436285.1 and ENSP00000410474.2
# Identical similarity for: ENSP00000410474.2 with ENSP00000410474.2 and ENSP00000338615.5
# Identical similarity for: ENSP00000410474.2 with ENSP00000410474.2 and ENSP00000434630.1
# Identical similarity for: ENSP00000410474.2 with ENSP00000410474.2 and ENSP00000436285.1
# Identical similarity for: ENSP00000410474.2 with ENSP00000410474.2 and ENSP00000410474.2
# Identical similarity for: ENSP00000481909.1 with ENSP00000338615.5 and ENSP00000434630.1
# Identical similarity for: ENSP00000481909.1 with ENSP00000338615.5 and ENSP00000436285.1
# Identical similarity for: ENSP00000481909.1 with ENSP00000338615.5 and ENSP00000410474.2
# Identical similarity for: ENSP00000434424.1 with ENSP00000338615.5 and ENSP00000434630.1
# Identical similarity for: ENSP00000434424.1 with ENSP00000338615.5 and ENSP00000436285.1
# Identical similarity for: ENSP00000434424.1 with ENSP00000338615.5 and ENSP00000410474.2
# Identical similarity for: ENSP00000415822.2 with ENSP00000415822.2 and ENSP00000415822.2
# Identical similarity for: ENSP00000498905.1 with ENSP00000498905.1 and ENSP00000498905.1
# Identical similarity for: ENSP00000498905.1 with ENSP00000498905.1 and ENSP00000381273.2
# Identical similarity for: ENSP00000381273.2 with ENSP00000381273.2 and ENSP00000498905.1
# Identical similarity for: ENSP00000381273.2 with ENSP00000381273.2 and ENSP00000381273.2
# Identical similarity for: ENSP00000360709.5 with ENSP00000360709.5 and ENSP00000360709.5
# Identical similarity for: ENSP00000360709.5 with ENSP00000360709.5 and ENSP00000325875.3
# Identical similarity for: ENSP00000360709.5 with ENSP00000360709.5 and ENSP00000360609.1
# Identical similarity for: ENSP00000360709.5 with ENSP00000360709.5 and ENSP00000481908.1
# Identical similarity for: ENSP00000325875.3 with ENSP00000325875.3 and ENSP00000360709.5
# Identical similarity for: ENSP00000325875.3 with ENSP00000325875.3 and ENSP00000325875.3
# Identical similarity for: ENSP00000325875.3 with ENSP00000325875.3 and ENSP00000360609.1
# Identical similarity for: ENSP00000325875.3 with ENSP00000325875.3 and ENSP00000481908.1
# Identical similarity for: ENSP00000360609.1 with ENSP00000360609.1 and ENSP00000360709.5
# Identical similarity for: ENSP00000360609.1 with ENSP00000360609.1 and ENSP00000325875.3
# Identical similarity for: ENSP00000360609.1 with ENSP00000360609.1 and ENSP00000360609.1
# Identical similarity for: ENSP00000360609.1 with ENSP00000360609.1 and ENSP00000481908.1
# Identical similarity for: ENSP00000481908.1 with ENSP00000481908.1 and ENSP00000360709.5
# Identical similarity for: ENSP00000481908.1 with ENSP00000481908.1 and ENSP00000325875.3
# Identical similarity for: ENSP00000481908.1 with ENSP00000481908.1 and ENSP00000360609.1
# Identical similarity for: ENSP00000481908.1 with ENSP00000481908.1 and ENSP00000481908.1
# Identical similarity for: ENSP00000431962.1 with ENSP00000431962.1 and ENSP00000431962.1
# Identical similarity for: ENSP00000431962.1 with ENSP00000437185.1 and ENSP00000357121.2
# Identical similarity for: ENSP00000431962.1 with ENSP00000437185.1 and ENSP00000436706.1
# Identical similarity for: ENSP00000398516.2 with ENSP00000398516.2 and ENSP00000398516.2
# Identical similarity for: ENSP00000436617.1 with ENSP00000437185.1 and ENSP00000357121.2
# Identical similarity for: ENSP00000436617.1 with ENSP00000437185.1 and ENSP00000436706.1
# Identical similarity for: ENSP00000437185.1 with ENSP00000437185.1 and ENSP00000437185.1
# Identical similarity for: ENSP00000437185.1 with ENSP00000437185.1 and ENSP00000357121.2
# Identical similarity for: ENSP00000437185.1 with ENSP00000437185.1 and ENSP00000436706.1
# Identical similarity for: ENSP00000433257.1 with ENSP00000437185.1 and ENSP00000357121.2
# Identical similarity for: ENSP00000433257.1 with ENSP00000437185.1 and ENSP00000436706.1
# Identical similarity for: ENSP00000357121.2 with ENSP00000357121.2 and ENSP00000437185.1
# Identical similarity for: ENSP00000357121.2 with ENSP00000357121.2 and ENSP00000357121.2
# Identical similarity for: ENSP00000357121.2 with ENSP00000357121.2 and ENSP00000436706.1
# Identical similarity for: ENSP00000436706.1 with ENSP00000436706.1 and ENSP00000437185.1
# Identical similarity for: ENSP00000436706.1 with ENSP00000436706.1 and ENSP00000357121.2
# Identical similarity for: ENSP00000436706.1 with ENSP00000436706.1 and ENSP00000436706.1
# Identical similarity for: ENSP00000357118.2 with ENSP00000357118.2 and ENSP00000431962.1
# Identical similarity for: ENSP00000357118.2 with ENSP00000437185.1 and ENSP00000357121.2
# Identical similarity for: ENSP00000357118.2 with ENSP00000437185.1 and ENSP00000436706.1
# Identical similarity for: ENSP00000354526.2 with ENSP00000354526.2 and ENSP00000431962.1
# Identical similarity for: ENSP00000354526.2 with ENSP00000437185.1 and ENSP00000357121.2
# Identical similarity for: ENSP00000354526.2 with ENSP00000437185.1 and ENSP00000436706.1
# Identical similarity for: ENSP00000233121.2 with ENSP00000233121.2 and ENSP00000233121.2
# Identical similarity for: ENSP00000364721.5 with ENSP00000364721.5 and ENSP00000364721.5
# Identical similarity for: ENSP00000233121.2 with ENSP00000233121.2 and ENSP00000233121.2
# Identical similarity for: ENSP00000422212.1 with ENSP00000422212.1 and ENSP00000422212.1
# Identical similarity for: ENSP00000286301.3 with ENSP00000286301.3 and ENSP00000286301.3
# Identical similarity for: ENSP00000261799.4 with ENSP00000261799.4 and ENSP00000261799.4
# Identical similarity for: ENSP00000227758.2 with ENSP00000227758.2 and ENSP00000227758.2
# Identical similarity for: ENSP00000328511.6 with ENSP00000328511.6 and ENSP00000328511.6
# ...
# Identical similarity for: ENSP00000379281.3 with ENSP00000379281.3 and ENSP00000379281.3
# Identical similarity for: ENSP00000379281.3 with ENSP00000379281.3 and ENSP00000395114.2
# Identical similarity for: ENSP00000379281.3 with ENSP00000379281.3 and ENSP00000379288.2
# Identical similarity for: ENSP00000379281.3 with ENSP00000379281.3 and ENSP00000398599.1
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000379287.2
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000395114.2 with ENSP00000395114.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000430058.1 with ENSP00000379287.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000430058.1 with ENSP00000379287.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000430058.1 with ENSP00000379287.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000430058.1 with ENSP00000379287.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000430058.1 with ENSP00000379287.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000430058.1 with ENSP00000379287.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000430058.1 with ENSP00000379287.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000429041.1 with ENSP00000379287.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000429041.1 with ENSP00000379287.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000429041.1 with ENSP00000379287.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000429041.1 with ENSP00000379287.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000429041.1 with ENSP00000379287.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000429041.1 with ENSP00000379287.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000429041.1 with ENSP00000379287.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000416551.1 with ENSP00000379287.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000416551.1 with ENSP00000379287.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000416551.1 with ENSP00000379287.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000416551.1 with ENSP00000379287.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000416551.1 with ENSP00000379287.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000416551.1 with ENSP00000379287.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000416551.1 with ENSP00000379287.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000394880.1 with ENSP00000379287.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000394880.1 with ENSP00000379287.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000394880.1 with ENSP00000379287.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000394880.1 with ENSP00000379287.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000394880.1 with ENSP00000379287.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000394880.1 with ENSP00000379287.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000394880.1 with ENSP00000379287.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000428381.1 with ENSP00000379287.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000428381.1 with ENSP00000379287.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000428381.1 with ENSP00000379287.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000428381.1 with ENSP00000379287.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000428381.1 with ENSP00000379287.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000428381.1 with ENSP00000379287.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000428381.1 with ENSP00000379287.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000430219.1 with ENSP00000379287.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000430219.1 with ENSP00000379287.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000430219.1 with ENSP00000379287.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000430219.1 with ENSP00000379287.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000430219.1 with ENSP00000379287.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000430219.1 with ENSP00000379287.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000430219.1 with ENSP00000379287.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000379287.2
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000379286.3
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000309503.3
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000379283.2
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000379281.3
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000395114.2
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000379288.2
# Identical similarity for: ENSP00000379288.2 with ENSP00000379288.2 and ENSP00000398599.1
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000379287.2
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000379286.3
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000309503.3
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000379283.2
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000379281.3
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000395114.2
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000379288.2
# Identical similarity for: ENSP00000398599.1 with ENSP00000398599.1 and ENSP00000398599.1
# Identical similarity for: ENSP00000338093.3 with ENSP00000338093.3 and ENSP00000338093.3
# Identical similarity for: ENSP00000364486.3 with ENSP00000364486.3 and ENSP00000364486.3
# Identical similarity for: ENSP00000399558.1 with ENSP00000399558.1 and ENSP00000399558.1
# Identical similarity for: ENSP00000399558.1 with ENSP00000282077.2 and ENSP00000386985.1
# Identical similarity for: ENSP00000406608.1 with ENSP00000282077.2 and ENSP00000386985.1
# Identical similarity for: ENSP00000282077.2 with ENSP00000282077.2 and ENSP00000282077.2
# Identical similarity for: ENSP00000282077.2 with ENSP00000282077.2 and ENSP00000386985.1
# Identical similarity for: ENSP00000376352.2 with ENSP00000282077.2 and ENSP00000386985.1
# Identical similarity for: ENSP00000386985.1 with ENSP00000386985.1 and ENSP00000282077.2
# Identical similarity for: ENSP00000386985.1 with ENSP00000386985.1 and ENSP00000386985.1
# Identical similarity for: ENSP00000413629.1 with ENSP00000282077.2 and ENSP00000386985.1
# Identical similarity for: ENSP00000399160.1 with ENSP00000282077.2 and ENSP00000386985.1
# Identical similarity for: ENSP00000388366.1 with ENSP00000388366.1 and ENSP00000399558.1
# Identical similarity for: ENSP00000388366.1 with ENSP00000282077.2 and ENSP00000386985.1
# Identical similarity for: ENSP00000365735.2 with ENSP00000365735.2 and ENSP00000365735.2
# Identical similarity for: ENSP00000221561.7 with ENSP00000221561.7 and ENSP00000221561.7
# Identical similarity for: ENSP00000317537.3 with ENSP00000317537.3 and ENSP00000317537.3
# Identical similarity for: ENSP00000246112.3 with ENSP00000246112.3 and ENSP00000246112.3
# Identical similarity for: ENSP00000452871.1 with ENSP00000452871.1 and ENSP00000452871.1
# Identical similarity for: ENSP00000452871.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000452871.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000319233.8 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000319233.8 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000452803.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000452803.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000453219.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000453219.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000454141.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000454141.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000453081.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000453081.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000453760.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000453760.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000452933.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000452933.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000453083.1 with ENSP00000453083.1 and ENSP00000453083.1
# Identical similarity for: ENSP00000453083.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000453083.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000453373.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000453373.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000442594.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000442594.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000452881.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000452881.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000415057.3 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000415057.3 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000454029.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000454029.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000453107.1 with ENSP00000453107.1 and ENSP00000453083.1
# Identical similarity for: ENSP00000453107.1 with ENSP00000453107.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000453107.1 with ENSP00000453107.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000453435.1 with ENSP00000453435.1 and ENSP00000453083.1
# Identical similarity for: ENSP00000453435.1 with ENSP00000453435.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000453435.1 with ENSP00000453435.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000394717.2 with ENSP00000394717.2 and ENSP00000452871.1
# Identical similarity for: ENSP00000394717.2 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000394717.2 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000452809.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000452809.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000457641.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000457641.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000456178.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000456178.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000485965.1 with ENSP00000453083.1 and ENSP00000453107.1
# Identical similarity for: ENSP00000485965.1 with ENSP00000453083.1 and ENSP00000453435.1
# Identical similarity for: ENSP00000262953.5 with ENSP00000262953.5 and ENSP00000262953.5
# Identical similarity for: ENSP00000466542.1 with ENSP00000466542.1 and ENSP00000466542.1
# Identical similarity for: ENSP00000269848.6 with ENSP00000269848.6 and ENSP00000269848.6
# Identical similarity for: ENSP00000336740.2 with ENSP00000336740.2 and ENSP00000336740.2
# Identical similarity for: ENSP00000444452.1 with ENSP00000444452.1 and ENSP00000444452.1
# Identical similarity for: ENSP00000452789.1 with ENSP00000452789.1 and ENSP00000452789.1
# Identical similarity for: ENSP00000332256.5 with ENSP00000332256.5 and ENSP00000332256.5
# Identical similarity for: ENSP00000297785.3 with ENSP00000297785.3 and ENSP00000297785.3
# Identical similarity for: ENSP00000441364.1 with ENSP00000441364.1 and ENSP00000441364.1
# Identical similarity for: ENSP00000441364.1 with ENSP00000276079.8 and ENSP00000362963.3
# Identical similarity for: ENSP00000441364.1 with ENSP00000276079.8 and ENSP00000362947.1
# Identical similarity for: ENSP00000362963.3 with ENSP00000362963.3 and ENSP00000276079.8
# Identical similarity for: ENSP00000362963.3 with ENSP00000362963.3 and ENSP00000362963.3
# Identical similarity for: ENSP00000362963.3 with ENSP00000362963.3 and ENSP00000362947.1
# Identical similarity for: ENSP00000362947.1 with ENSP00000362947.1 and ENSP00000276079.8
# Identical similarity for: ENSP00000362947.1 with ENSP00000362947.1 and ENSP00000362963.3
# Identical similarity for: ENSP00000362947.1 with ENSP00000362947.1 and ENSP00000362947.1
# Identical similarity for: ENSP00000410299.1 with ENSP00000276079.8 and ENSP00000362963.3
# Identical similarity for: ENSP00000410299.1 with ENSP00000276079.8 and ENSP00000362947.1
# Identical similarity for: ENSP00000413350.1 with ENSP00000276079.8 and ENSP00000362963.3
# Identical similarity for: ENSP00000413350.1 with ENSP00000276079.8 and ENSP00000362947.1
# Identical similarity for: ENSP00000415777.1 with ENSP00000276079.8 and ENSP00000362963.3
# Identical similarity for: ENSP00000415777.1 with ENSP00000276079.8 and ENSP00000362947.1
# Identical similarity for: ENSP00000406673.1 with ENSP00000276079.8 and ENSP00000362963.3
# Identical similarity for: ENSP00000406673.1 with ENSP00000276079.8 and ENSP00000362947.1
# Identical similarity for: ENSP00000409773.1 with ENSP00000276079.8 and ENSP00000362963.3
# Identical similarity for: ENSP00000409773.1 with ENSP00000276079.8 and ENSP00000362947.1
# Identical similarity for: ENSP00000436038.1 with ENSP00000436038.1 and ENSP00000436038.1
# Identical similarity for: ENSP00000436038.1 with ENSP00000436038.1 and ENSP00000435921.1
# Identical similarity for: ENSP00000436038.1 with ENSP00000343966.4 and ENSP00000481916.1
# Identical similarity for: ENSP00000435921.1 with ENSP00000435921.1 and ENSP00000436038.1
# Identical similarity for: ENSP00000435921.1 with ENSP00000435921.1 and ENSP00000435921.1
# Identical similarity for: ENSP00000435921.1 with ENSP00000343966.4 and ENSP00000481916.1
# Identical similarity for: ENSP00000488975.1 with ENSP00000436038.1 and ENSP00000435921.1
# Identical similarity for: ENSP00000488975.1 with ENSP00000343966.4 and ENSP00000481916.1
# Identical similarity for: ENSP00000393069.1 with ENSP00000436038.1 and ENSP00000435921.1
# Identical similarity for: ENSP00000393069.1 with ENSP00000343966.4 and ENSP00000481916.1
# Identical similarity for: ENSP00000481916.1 with ENSP00000481916.1 and ENSP00000343966.4
# Identical similarity for: ENSP00000481916.1 with ENSP00000481916.1 and ENSP00000481916.1
# Identical similarity for: ENSP00000366650.3 with ENSP00000366650.3 and ENSP00000366650.3
# Identical similarity for: ENSP00000431657.1 with ENSP00000431657.1 and ENSP00000431657.1
# Identical similarity for: ENSP00000381526.3 with ENSP00000381526.3 and ENSP00000381526.3
# Identical similarity for: ENSP00000343690.5 with ENSP00000343690.5 and ENSP00000343690.5
# Identical similarity for: ENSP00000339850.3 with ENSP00000339850.3 and ENSP00000339850.3
